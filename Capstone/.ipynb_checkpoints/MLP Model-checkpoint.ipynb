# %% [markdown]
# # Multi-layer Perceptron Regressor - Model

# %% [markdown]
# This is the implementation of an Multi-layer Perceptron Regression Model as an attempt at a baseline Neural Network implementation.
#
# Some of the hyperparameters are tuned via a GridSearchCV.

# %% [markdown]
# ## Imports

# %%
import pandas as pd
import numpy as np
import seaborn as sns

from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline

import warnings
warnings.filterwarnings("ignore")

import matplotlib.pyplot as plt
# %matplotlib inline

from IPython.display import set_matplotlib_formats
set_matplotlib_formats('pdf', 'png')
pd.options.display.float_format = '{:.4f}'.format
rc={'savefig.dpi': 75, 'figure.autolayout': False, 'figure.figsize': [12, 8], 'axes.labelsize': 18,\
   'axes.titlesize': 18, 'font.size': 18, 'lines.linewidth': 2.0, 'lines.markersize': 8, 'legend.fontsize': 16,\
   'xtick.labelsize': 16, 'ytick.labelsize': 16}

sns.set(style='dark',rc=rc)

pd.options.display.max_rows = 400
pd.options.display.max_seq_items = 200

default_color = '#56B4E9'
colormap = plt.cm.cool

# %%
from sklearn.neural_network import MLPRegressor
from sklearn.model_selection import KFold, cross_validate, GridSearchCV

# %% [markdown]
# # Loading Data

# %%
df_1_all = pd.read_csv('Cleaned Data/df_1_all_reg.csv')
df_2_all = pd.read_csv('Cleaned Data/df_2_all_reg.csv')
df_3_all = pd.read_csv('Cleaned Data/df_3_all_reg.csv')
df_4_all = pd.read_csv('Cleaned Data/df_4_all_reg.csv')
df_5_all = pd.read_csv('Cleaned Data/df_5_all_reg.csv')
df_6_all = pd.read_csv('Cleaned Data/df_6_all_reg.csv')

# %%
df_1_2017 = pd.read_csv('Cleaned Data/df_1_2017_reg.csv')
df_2_2017 = pd.read_csv('Cleaned Data/df_2_2017_reg.csv')
df_3_2017 = pd.read_csv('Cleaned Data/df_3_2017_reg.csv')
df_4_2017 = pd.read_csv('Cleaned Data/df_4_2017_reg.csv')
df_5_2017 = pd.read_csv('Cleaned Data/df_5_2017_reg.csv')
df_6_2017 = pd.read_csv('Cleaned Data/df_6_2017_reg.csv')

# %% [markdown]
# ## Utilitary Functions and Variables

# %%
'''
Cross Validation Function
Takes in training set features and target, the model, and number of splits for K-Fold, 
returns the mean of the K scores.

'''
def cross_val(X, y, model):
    kfold = KFold(n_splits=5, random_state=seed, shuffle = True)
    results = cross_validate(model, X, y, cv=kfold, scoring=scoring)
    print('MAE: %.4f (%.4f)' % (results['test_MAE'].mean()*-1, results['test_MAE'].std()))
    print('MSE: %.4f (%.4f)' % (results['test_MSE'].mean()*-1, results['test_MSE'].std()))
    print('-----------------------------------------')

# %%
'''
Plot Figure Helper Function
Takes in the predicted scores and original target scores and returns a graph.

'''
def plot_figure(scores, pred):
    plt.figure(figsize=(16,6))
    plt.plot(range(scores.shape[0]), scores, color='royalblue', alpha=.8, label='True')
    plt.plot(range(pred.shape[0]), pred, color='tomato', alpha=.8, label='Predicted')
    plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
    plt.title("Predicted vs True Values")
    plt.xlabel("Entries")
    plt.ylabel("Points")

# %%
'''
Show Predictions Function
Takes in the model, training set features and target, and the original dataframe, 
returns a graph with the predicted values as compared to the original target values.

'''
def show_preds(estimator, X, y, df):
    pred = estimator.predict(X)
    df['predictions'] = pred
    plot_figure(y, pred)
    #return df[['Athlete_Name', 'Pontos', 'predictions', 'Preco', 'Rodada']].sort_values(by=['predictions'], ascending=False)

# %%
'''
Prediction Function
Takes in Dataframe, Model, Model Parameters, number of players per position, and returns a list with 
the following features: Athlete ID, Position ID, Points, Round, Predicted Scores, Price, and Price Variation
for the chosen athletes.

'''
def get_preds(df, model, model_params, count):
    lst = []
    for rodada in list_rounds:
        df_rodada = df[df.Round == rodada]
        df_rodada['predictions'] = model.predict(df_rodada[model_params])
        df_sorted = df_rodada.sort_values(by=['predictions'], ascending=False).head(count)
        for i in range(count):
            lst.append([df_sorted.AthleteID.values[i], df_sorted.PositionID.values[i], 
                        df_sorted.Points.values[i], rodada, df_sorted.predictions.values[i],
                        df_sorted.Price.values[i], df_sorted.Price_Variation.values[i]])
    return lst

# %%
'''
Define Model Function
Takes the model and passes it through a preprocessing pipeline step for normalization.
Returns the pipeline.

'''
def def_model(model):
    # create pipeline
    estimators = []
    estimators.append(('model', model))
    model_ = Pipeline(estimators)
    
    return model_

# %%
seed = 42
np.random.seed(seed)

# %%
# Scoring Functions for the Regressor
scoring = {'MAE': 'neg_mean_absolute_error',
           'MSE': 'neg_mean_squared_error'}

# %%
base_params = ['Away', 'avg_Assists',
       'avg_Difficult_Saves', 'avg_Fouls_Conceded', 'avg_Fouls_Received',
       'avg_Game_Without_Being_Scored', 'avg_Goals', 'avg_Goals_Conceded',
       'avg_Missed_Passes', 'avg_Missed_Penalty', 'avg_Offsides',
       'avg_Own_Goals', 'avg_Penalty_Saves', 'avg_Points', 'avg_Price',
       'avg_Red_Card', 'avg_Shot_Missed', 'avg_Shot_Saved',
       'avg_Shot_on_Post', 'avg_Stolen_Balls', 'avg_Yellow_Card',
               
       'avg_team_avg_1_Difficult_Saves', 'avg_team_avg_1_Points',
       'avg_team_avg_1_Assists', 'avg_team_avg_1_Fouls_Conceded',
       'avg_team_avg_1_Fouls_Received',
       'avg_team_avg_1_Game_Without_Being_Scored',
       'avg_team_avg_1_Goals_Conceded', 'avg_team_avg_1_Missed_Passes',
       'avg_team_avg_1_Penalty_Saves', 'avg_team_avg_1_Price',
       'avg_team_avg_1_Red_Card', 'avg_team_avg_1_Shot_Saved',
       'avg_team_avg_1_Stolen_Balls', 'avg_team_avg_1_Yellow_Card',
               
       'avg_team_avg_2_Assists', 'avg_team_avg_2_Fouls_Conceded',
       'avg_team_avg_2_Fouls_Received',
       'avg_team_avg_2_Game_Without_Being_Scored', 'avg_team_avg_2_Goals',
       'avg_team_avg_2_Missed_Passes', 'avg_team_avg_2_Missed_Penalty',
       'avg_team_avg_2_Offsides', 'avg_team_avg_2_Own_Goals',
       'avg_team_avg_2_Price', 'avg_team_avg_2_Points',
       'avg_team_avg_2_Red_Card', 'avg_team_avg_2_Shot_Missed',
       'avg_team_avg_2_Shot_Saved', 'avg_team_avg_2_Shot_on_Post',
       'avg_team_avg_2_Stolen_Balls', 'avg_team_avg_2_Yellow_Card',
               
       'avg_team_avg_3_Assists', 'avg_team_avg_3_Fouls_Conceded',
       'avg_team_avg_3_Fouls_Received',
       'avg_team_avg_3_Game_Without_Being_Scored', 'avg_team_avg_3_Goals',
       'avg_team_avg_3_Missed_Passes', 'avg_team_avg_3_Missed_Penalty',
       'avg_team_avg_3_Offsides', 'avg_team_avg_3_Own_Goals',
       'avg_team_avg_3_Points', 'avg_team_avg_3_Price',
       'avg_team_avg_3_Red_Card', 'avg_team_avg_3_Shot_Missed',
       'avg_team_avg_3_Shot_Saved', 'avg_team_avg_3_Shot_on_Post',
       'avg_team_avg_3_Stolen_Balls', 'avg_team_avg_3_Yellow_Card',
               
       'avg_team_avg_4_Assists', 'avg_team_avg_4_Fouls_Conceded',
       'avg_team_avg_4_Fouls_Received',
       'avg_team_avg_4_Game_Without_Being_Scored', 'avg_team_avg_4_Goals',
       'avg_team_avg_4_Missed_Passes', 'avg_team_avg_4_Missed_Penalty',
       'avg_team_avg_4_Offsides', 'avg_team_avg_4_Own_Goals',
       'avg_team_avg_4_Points', 'avg_team_avg_4_Price',
       'avg_team_avg_4_Red_Card', 'avg_team_avg_4_Shot_Missed',
       'avg_team_avg_4_Shot_Saved', 'avg_team_avg_4_Shot_on_Post',
       'avg_team_avg_4_Stolen_Balls', 'avg_team_avg_4_Yellow_Card',
               
       'avg_team_avg_5_Assists', 'avg_team_avg_5_Fouls_Conceded',
       'avg_team_avg_5_Fouls_Received',
       'avg_team_avg_5_Game_Without_Being_Scored', 'avg_team_avg_5_Goals',
       'avg_team_avg_5_Missed_Passes', 'avg_team_avg_5_Missed_Penalty',
       'avg_team_avg_5_Offsides', 'avg_team_avg_5_Own_Goals',
       'avg_team_avg_5_Points', 'avg_team_avg_5_Price',
       'avg_team_avg_5_Red_Card', 'avg_team_avg_5_Shot_Missed',
       'avg_team_avg_5_Shot_Saved', 'avg_team_avg_5_Shot_on_Post',
       'avg_team_avg_5_Stolen_Balls', 'avg_team_avg_5_Yellow_Card',
               
       'avg_team_avg_6_Points', 'avg_team_avg_6_Price',
               
       'opp_avg_team_avg_1_Difficult_Saves', 'opp_avg_team_avg_1_Points',
       'opp_avg_team_avg_1_Assists', 'opp_avg_team_avg_1_Fouls_Conceded',
       'opp_avg_team_avg_1_Fouls_Received',
       'opp_avg_team_avg_1_Game_Without_Being_Scored',
       'opp_avg_team_avg_1_Goals_Conceded',
       'opp_avg_team_avg_1_Missed_Passes',
       'opp_avg_team_avg_1_Penalty_Saves', 'opp_avg_team_avg_1_Price',
       'opp_avg_team_avg_1_Red_Card', 'opp_avg_team_avg_1_Shot_Saved',
       'opp_avg_team_avg_1_Stolen_Balls',
       'opp_avg_team_avg_1_Yellow_Card',
               
               'opp_avg_team_avg_2_Assists',
       'opp_avg_team_avg_2_Fouls_Conceded',
       'opp_avg_team_avg_2_Fouls_Received',
       'opp_avg_team_avg_2_Game_Without_Being_Scored',
       'opp_avg_team_avg_2_Goals', 'opp_avg_team_avg_2_Missed_Passes',
       'opp_avg_team_avg_2_Missed_Penalty', 'opp_avg_team_avg_2_Offsides',
       'opp_avg_team_avg_2_Own_Goals', 'opp_avg_team_avg_2_Price',
       'opp_avg_team_avg_2_Points', 'opp_avg_team_avg_2_Red_Card',
       'opp_avg_team_avg_2_Shot_Missed', 'opp_avg_team_avg_2_Shot_Saved',
       'opp_avg_team_avg_2_Shot_on_Post',
       'opp_avg_team_avg_2_Stolen_Balls',
       'opp_avg_team_avg_2_Yellow_Card', 
               
               'opp_avg_team_avg_3_Assists',
       'opp_avg_team_avg_3_Fouls_Conceded',
       'opp_avg_team_avg_3_Fouls_Received',
       'opp_avg_team_avg_3_Game_Without_Being_Scored',
       'opp_avg_team_avg_3_Goals', 'opp_avg_team_avg_3_Missed_Passes',
       'opp_avg_team_avg_3_Missed_Penalty', 'opp_avg_team_avg_3_Offsides',
       'opp_avg_team_avg_3_Own_Goals', 'opp_avg_team_avg_3_Points',
       'opp_avg_team_avg_3_Price', 'opp_avg_team_avg_3_Red_Card',
       'opp_avg_team_avg_3_Shot_Missed', 'opp_avg_team_avg_3_Shot_Saved',
       'opp_avg_team_avg_3_Shot_on_Post',
       'opp_avg_team_avg_3_Stolen_Balls',
       'opp_avg_team_avg_3_Yellow_Card',
               
               'opp_avg_team_avg_4_Assists',
       'opp_avg_team_avg_4_Fouls_Conceded',
       'opp_avg_team_avg_4_Fouls_Received',
       'opp_avg_team_avg_4_Game_Without_Being_Scored',
       'opp_avg_team_avg_4_Goals', 'opp_avg_team_avg_4_Missed_Passes',
       'opp_avg_team_avg_4_Missed_Penalty', 'opp_avg_team_avg_4_Offsides',
       'opp_avg_team_avg_4_Own_Goals', 'opp_avg_team_avg_4_Points',
       'opp_avg_team_avg_4_Price', 'opp_avg_team_avg_4_Red_Card',
       'opp_avg_team_avg_4_Shot_Missed', 'opp_avg_team_avg_4_Shot_Saved',
       'opp_avg_team_avg_4_Shot_on_Post',
       'opp_avg_team_avg_4_Stolen_Balls',
       'opp_avg_team_avg_4_Yellow_Card', 
               
               'opp_avg_team_avg_5_Assists',
       'opp_avg_team_avg_5_Fouls_Conceded',
       'opp_avg_team_avg_5_Fouls_Received',
       'opp_avg_team_avg_5_Game_Without_Being_Scored',
       'opp_avg_team_avg_5_Goals', 'opp_avg_team_avg_5_Missed_Passes',
       'opp_avg_team_avg_5_Missed_Penalty', 'opp_avg_team_avg_5_Offsides',
       'opp_avg_team_avg_5_Own_Goals', 'opp_avg_team_avg_5_Points',
       'opp_avg_team_avg_5_Price', 'opp_avg_team_avg_5_Red_Card',
       'opp_avg_team_avg_5_Shot_Missed', 'opp_avg_team_avg_5_Shot_Saved',
       'opp_avg_team_avg_5_Shot_on_Post',
       'opp_avg_team_avg_5_Stolen_Balls',
       'opp_avg_team_avg_5_Yellow_Card', 
               
               'opp_avg_team_avg_6_Points', 'opp_avg_team_avg_6_Price'
       ]

# %% [markdown]
# # Implementation

# %% [markdown]
# **MLP Model implementation for each position.**
#
# Each implementation follows the followng steps:
# 1. An initial filter of features is made in order to only keep the features that have valid values for the training and testing set.
# 2. The baseline model is defined via a pipeline.
# 3. A cross-validation of the model is done using the K-Fold split strategy, recording the corresponding MAE and MSE.
# 4. The model is fitted to the data.
# 5. A graph is drawn showing the predicted Scores as compared to the true Scores for the training set, for visualization purposes.
#
# This process is repeated for every position.

# %% [markdown]
# ## Position 1

# %% [markdown]
# For Position 1, since there is only one player for the position, I remove the values associated to the team average for the position, as they end up being a duplicate feature.

# %%
model_params_1 = df_1_all[base_params].mean()[df_1_all[base_params].mean() > 0.01].keys().values.tolist()

# %%
model_params_1 = [e for e in model_params_1 if e not in (
    'avg_team_avg_1_Difficult_Saves', 'avg_team_avg_1_Points',
       'avg_team_avg_1_Assists', 'avg_team_avg_1_Fouls_Conceded',
       'avg_team_avg_1_Fouls_Received',
       'avg_team_avg_1_Game_Without_Being_Scored', 'avg_team_avg_1_Goals',
       'avg_team_avg_1_Goals_Conceded', 'avg_team_avg_1_Missed_Passes',
       'avg_team_avg_1_Missed_Penalty', 'avg_team_avg_1_Offsides',
       'avg_team_avg_1_Own_Goals', 'avg_team_avg_1_Penalty_Saves',
       'avg_team_avg_1_Price', 'avg_team_avg_1_Red_Card',
       'avg_team_avg_1_Shot_Missed', 'avg_team_avg_1_Shot_Saved',
       'avg_team_avg_1_Shot_on_Post', 'avg_team_avg_1_Stolen_Balls',
       'avg_team_avg_1_Yellow_Card')]

# %%
X_1 = df_1_all[model_params_1].values
y_1 = df_1_all['Points'].values

print(X_1.shape)
print(y_1.shape)
# Out:
# (2015, 137)
# (2015,)

# %%
mlp_1 = MLPRegressor(
     hidden_layer_sizes=(100, ), activation='relu', solver='adam', alpha=0.0001, 
     batch_size='auto', learning_rate='constant', learning_rate_init=0.001, 
     power_t=0.5, max_iter=200, shuffle=True, random_state=seed, tol=0.0001, 
     verbose=False, warm_start=False, momentum=0.9, nesterovs_momentum=True, 
     early_stopping=False, validation_fraction=0.1, beta_1=0.9, beta_2=0.999, 
     epsilon=1e-08)

# %%
model_1 = def_model(mlp_1)

# %%
cross_val(X_1, y_1, model_1)
# Out:
# MAE: 4.5808 (0.1263)
# MSE: 31.7922 (1.8654)
# -----------------------------------------

# %%
model_1.fit(X_1, y_1)
# Out:
# Pipeline(memory=None,
#      steps=[('model', MLPRegressor(activation='relu', alpha=0.0001, batch_size='auto', beta_1=0.9,
#        beta_2=0.999, early_stopping=False, epsilon=1e-08,
#        hidden_layer_sizes=(100,), learning_rate='constant',
#        learning_rate_init=0.001, max_iter=200, momentum=0.9,
#        nesterovs_momentum=True, power_t=0.5, random_state=42, shuffle=True,
#        solver='adam', tol=0.0001, validation_fraction=0.1, verbose=False,
#        warm_start=False))])

# %%
show_preds(model_1, X_1, y_1, df_1_all)

# %% [markdown]
# ## Position 2

# %%
model_params_2 = df_2_all[base_params].mean()[df_2_all[base_params].mean() > 0.01].keys().values.tolist()

# %%
X_2 = df_2_all[model_params_2].values
y_2 = df_2_all['Points'].values

print(X_2.shape)
print(y_2.shape)
# Out:
# (4040, 149)
# (4040,)

# %%
mlp_2 = MLPRegressor(
     hidden_layer_sizes=(100, ), activation='relu', solver='adam', alpha=0.0001, 
     batch_size='auto', learning_rate='constant', learning_rate_init=0.001, 
     power_t=0.5, max_iter=200, shuffle=True, random_state=seed, tol=0.0001, 
     verbose=False, warm_start=False, momentum=0.9, nesterovs_momentum=True, 
     early_stopping=False, validation_fraction=0.1, beta_1=0.9, beta_2=0.999, 
     epsilon=1e-08)

# %%
model_2 = def_model(mlp_2)

# %%
cross_val(X_2, y_2, model_2)
# Out:
# MAE: 3.3036 (0.0827)
# MSE: 17.8213 (1.2453)
# -----------------------------------------

# %%
mlp_2.fit(X_2, y_2)
# Out:
# MLPRegressor(activation='relu', alpha=0.0001, batch_size='auto', beta_1=0.9,
#        beta_2=0.999, early_stopping=False, epsilon=1e-08,
#        hidden_layer_sizes=(100,), learning_rate='constant',
#        learning_rate_init=0.001, max_iter=200, momentum=0.9,
#        nesterovs_momentum=True, power_t=0.5, random_state=42, shuffle=True,
#        solver='adam', tol=0.0001, validation_fraction=0.1, verbose=False,
#        warm_start=False)

# %%
show_preds(mlp_2, X_2, y_2, df_2_all)

# %% [markdown]
# ## Position 3

# %%
model_params_3 = df_3_all[base_params].mean()[df_3_all[base_params].mean() > 0.01].keys().values.tolist()

# %%
X_3 = df_3_all[model_params_3].values
y_3 = df_3_all['Points'].values

print(X_3.shape)
print(y_3.shape)
# Out:
# (4126, 149)
# (4126,)

# %%
mlp_3 = MLPRegressor(
     hidden_layer_sizes=(100, ), activation='relu', solver='adam', alpha=0.0001, 
     batch_size='auto', learning_rate='constant', learning_rate_init=0.001, 
     power_t=0.5, max_iter=200, shuffle=True, random_state=seed, tol=0.0001, 
     verbose=False, warm_start=False, momentum=0.9, nesterovs_momentum=True, 
     early_stopping=False, validation_fraction=0.1, beta_1=0.9, beta_2=0.999, 
     epsilon=1e-08)

# %%
cross_val(X_3, y_3, mlp_3)
# Out:
# MAE: 3.1767 (0.1595)
# MSE: 16.7656 (1.2963)
# -----------------------------------------

# %%
mlp_3.fit(X_3, y_3)
# Out:
# MLPRegressor(activation='relu', alpha=0.0001, batch_size='auto', beta_1=0.9,
#        beta_2=0.999, early_stopping=False, epsilon=1e-08,
#        hidden_layer_sizes=(100,), learning_rate='constant',
#        learning_rate_init=0.001, max_iter=200, momentum=0.9,
#        nesterovs_momentum=True, power_t=0.5, random_state=42, shuffle=True,
#        solver='adam', tol=0.0001, validation_fraction=0.1, verbose=False,
#        warm_start=False)

# %%
show_preds(mlp_3, X_3, y_3, df_3_all)

# %% [markdown]
# ## Position 4

# %%
model_params_4 = df_4_all[base_params].mean()[df_4_all[base_params].mean() > 0.01].keys().values.tolist()

# %%
X_4 = df_4_all[model_params_4].values
y_4 = df_4_all['Points'].values

print(X_4.shape)
print(y_4.shape)
# Out:
# (9736, 150)
# (9736,)

# %%
mlp_4 = MLPRegressor(
     hidden_layer_sizes=(100, ), activation='relu', solver='adam', alpha=0.0001, 
     batch_size='auto', learning_rate='constant', learning_rate_init=0.001, 
     power_t=0.5, max_iter=200, shuffle=True, random_state=seed, tol=0.0001, 
     verbose=False, warm_start=False, momentum=0.9, nesterovs_momentum=True, 
     early_stopping=False, validation_fraction=0.1, beta_1=0.9, beta_2=0.999, 
     epsilon=1e-08)

# %%
cross_val(X_4, y_4, mlp_4)
# Out:
# MAE: 2.9893 (0.0346)
# MSE: 15.7306 (0.6198)
# -----------------------------------------

# %%
mlp_4.fit(X_4, y_4)
# Out:
# MLPRegressor(activation='relu', alpha=0.0001, batch_size='auto', beta_1=0.9,
#        beta_2=0.999, early_stopping=False, epsilon=1e-08,
#        hidden_layer_sizes=(100,), learning_rate='constant',
#        learning_rate_init=0.001, max_iter=200, momentum=0.9,
#        nesterovs_momentum=True, power_t=0.5, random_state=42, shuffle=True,
#        solver='adam', tol=0.0001, validation_fraction=0.1, verbose=False,
#        warm_start=False)

# %%
show_preds(mlp_4, X_4, y_4, df_4_all)

# %% [markdown]
# ## Position 5

# %%
model_params_5 = df_5_all[base_params].mean()[df_5_all[base_params].mean() > 0.01].keys().values.tolist()

# %%
X_5 = df_5_all[model_params_5].values
y_5 = df_5_all['Points'].values

print(X_5.shape)
print(y_5.shape)
# Out:
# (6516, 150)
# (6516,)

# %%
mlp_5 = MLPRegressor(
     hidden_layer_sizes=(100, ), activation='relu', solver='adam', alpha=0.0001, 
     batch_size='auto', learning_rate='constant', learning_rate_init=0.001, 
     power_t=0.5, max_iter=200, shuffle=True, random_state=seed, tol=0.0001, 
     verbose=False, warm_start=False, momentum=0.9, nesterovs_momentum=True, 
     early_stopping=False, validation_fraction=0.1, beta_1=0.9, beta_2=0.999, 
     epsilon=1e-08)

# %%
cross_val(X_5, y_5, mlp_5)
# Out:
# MAE: 3.3911 (0.0960)
# MSE: 20.6485 (1.4861)
# -----------------------------------------

# %%
mlp_5.fit(X_5, y_5)
# Out:
# MLPRegressor(activation='relu', alpha=0.0001, batch_size='auto', beta_1=0.9,
#        beta_2=0.999, early_stopping=False, epsilon=1e-08,
#        hidden_layer_sizes=(100,), learning_rate='constant',
#        learning_rate_init=0.001, max_iter=200, momentum=0.9,
#        nesterovs_momentum=True, power_t=0.5, random_state=42, shuffle=True,
#        solver='adam', tol=0.0001, validation_fraction=0.1, verbose=False,
#        warm_start=False)

# %%
show_preds(mlp_5, X_5, y_5, df_5_all)

# %% [markdown]
# ## Position 6

# %% [markdown]
# For Position 6, since there is only one player for the position, I remove the values associated to the team average for the position, as they end up being a duplicate feature.

# %%
model_params_6 = df_6_all[base_params].mean()[df_6_all[base_params].mean() > 0.01].keys().values.tolist()

# %%
model_params_6 = [e for e in model_params_6 if e not in (
    'avg_team_avg_6_Points', 'avg_team_avg_6_Price')]

# %%
X_6 = df_6_all[model_params_6].values
y_6 = df_6_all['Points'].values

print(X_6.shape)
print(y_6.shape)
# Out:
# (2022, 136)
# (2022,)

# %%
mlp_6 = MLPRegressor(
     hidden_layer_sizes=(100, ), activation='relu', solver='adam', alpha=0.0001, 
     batch_size='auto', learning_rate='constant', learning_rate_init=0.001, 
     power_t=0.5, max_iter=200, shuffle=True, random_state=seed, tol=0.0001, 
     verbose=False, warm_start=False, momentum=0.9, nesterovs_momentum=True, 
     early_stopping=False, validation_fraction=0.1, beta_1=0.9, beta_2=0.999, 
     epsilon=1e-08)

# %%
cross_val(X_6, y_6, mlp_6)
# Out:
# MAE: 1.6886 (0.0558)
# MSE: 4.3100 (0.3206)
# -----------------------------------------

# %%
mlp_6.fit(X_6, y_6)
# Out:
# MLPRegressor(activation='relu', alpha=0.0001, batch_size='auto', beta_1=0.9,
#        beta_2=0.999, early_stopping=False, epsilon=1e-08,
#        hidden_layer_sizes=(100,), learning_rate='constant',
#        learning_rate_init=0.001, max_iter=200, momentum=0.9,
#        nesterovs_momentum=True, power_t=0.5, random_state=42, shuffle=True,
#        solver='adam', tol=0.0001, validation_fraction=0.1, verbose=False,
#        warm_start=False)

# %%
show_preds(mlp_6, X_6, y_6, df_6_all)

# %% [markdown]
# # Model Tuning

# %% [markdown]
# For the model tuning portion for the MLP models, the following steps are taken:
# 1. A parameter grid is established with ranges for the Hidden Layer Sizes, Activation, Learning Rate Initialization, and Alpha hyperparameters.
# 2. A GridSearchCV is created with the associated parameter grid.
# 3. The model is fitted to the data, using a K-Fold split (5).
# 4. The best parameters from the grid are selected and implemented on a modified MLP model.
# 5. This new MLP model is cross validated, fitted, and graphed, similarly to the original model.
#
# This process is repeated for all positions.

# %%
# Parameter Grid Definition
param_grid = {'hidden_layer_sizes': [50,100,150,200],
              'activation': ['logistic', 'relu'],
              'learning_rate_init': [0.01, 0.001, 0.0001],
              'alpha': [0.01, 0.001, 0.0001],
              }
base_MLP = MLPRegressor(activation='relu', alpha=0.0001, batch_size='auto', beta_1=0.9,
       beta_2=0.999, early_stopping=False, epsilon=1e-08,
       hidden_layer_sizes=(100,), learning_rate='constant',
       learning_rate_init=0.001, max_iter=1000, momentum=0.9,
       nesterovs_momentum=True, power_t=0.5, random_state=42,
       shuffle=True, solver='adam', tol=0.0001, validation_fraction=0.1,
       verbose=False, warm_start=False)

# %% [markdown]
# ## Position 1

# %%
# Create an estimator object with the estimator and parameter candidates.
kfold = KFold(n_splits=5, random_state=seed, shuffle = True)
mlp_1_GS = GridSearchCV(estimator=base_MLP, param_grid=param_grid, verbose=10,
                        scoring='neg_mean_absolute_error', cv=kfold)

# %%
mlp_1_GS.fit(X_1, y_1)
# Out:
# Fitting 5 folds for each of 72 candidates, totalling 360 fits
# [CV] activation=logistic, alpha=0.01, hidden_layer_sizes=50, learning_rate_init=0.01
# [CV]  activation=logistic, alpha=0.01, hidden_layer_sizes=50, learning_rate_init=0.01, score=-4.291778997113811, total=   0.2s
# [CV] activation=logistic, alpha=0.01, hidden_layer_sizes=50, learning_rate_init=0.01
# [CV]  activation=logistic, alpha=0.01, hidden_layer_sizes=50, learning_rate_init=0.01, score=-4.747282736672663, total=   0.0s
# [CV] activation=logistic, alpha=0.01, hidden_layer_sizes=50, learning_rate_init=0.01
# [CV]  activation=logistic, alpha=0.01, hidden_layer_sizes=50, learning_rate_init=0.01, score=-4.737707378140586, total=   0.0s
# [CV] activation=logistic, alpha=0.01, hidden_layer_sizes=50, learning_rate_init=0.01
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.2s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.2s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.3s remaining:    0.0s
# [CV]  activation=logistic, alpha=0.01, hidden_layer_sizes=50, learning_rate_init=0.01, score=-4.5428748458399, total=   0.0s
# [CV] activation=logistic, alpha=0.01, hidden_layer_sizes=50, learning_rate_init=0.01
# [CV]  activation=logistic, alpha=0.01, hidden_layer_sizes=50, learning_rate_init=0.01, score=-4.5908778255473734, total=   0.0s
# [CV] activation=logistic, alpha=0.01, hidden_layer_sizes=50, learning_rate_init=0.001
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.4s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    0.5s remaining:    0.0s
# [CV]  activation=logistic, alpha=0.01, hidden_layer_sizes=50, learning_rate_init=0.001, score=-4.286123369088587, total=   0.1s
# [CV] activation=logistic, alpha=0.01, hidden_layer_sizes=50, learning_rate_init=0.001
# [Parallel(n_jobs=1)]: Done   6 out of   6 | elapsed:    0.7s remaining:    0.0s
# [CV]  activation=logistic, alpha=0.01, hidden_layer_sizes=50, learning_rate_init=0.001, score=-4.731491650848738, total=   0.3s
# [CV] activation=logistic, alpha=0.01, hidden_layer_sizes=50, learning_rate_init=0.001
# [Parallel(n_jobs=1)]: Done   7 out of   7 | elapsed:    1.1s remaining:    0.0s
# [CV]  activation=logistic, alpha=0.01, hidden_layer_sizes=50, learning_rate_init=0.001, score=-4.723145620837012, total=   0.3s
# [CV] activation=logistic, alpha=0.01, hidden_layer_sizes=50, learning_rate_init=0.001
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed:    1.5s remaining:    0.0s
# [CV]  activation=logistic, alpha=0.01, hidden_layer_sizes=50, learning_rate_init=0.001, score=-4.491287763418048, total=   1.0s
# [CV] activation=logistic, alpha=0.01, hidden_layer_sizes=50, learning_rate_init=0.001
# [Parallel(n_jobs=1)]: Done   9 out of   9 | elapsed:    2.6s remaining:    0.0s
# [CV]  activation=logistic, alpha=0.01, hidden_layer_sizes=50, learning_rate_init=0.001, score=-4.568729806944783, total=   0.7s
# [CV] activation=logistic, alpha=0.01, hidden_layer_sizes=50, learning_rate_init=0.0001
# [CV]  activation=logistic, alpha=0.01, hidden_layer_sizes=50, learning_rate_init=0.0001, score=-4.251691601120025, total=   4.3s
# [CV] activation=logistic, alpha=0.01, hidden_layer_sizes=50, learning_rate_init=0.0001
# [CV]  activation=logistic, alpha=0.01, hidden_layer_sizes=50, learning_rate_init=0.0001, score=-4.7338165323474755, total=   3.6s
# [CV] activation=logistic, alpha=0.01, hidden_layer_sizes=50, learning_rate_init=0.0001
# [CV]  activation=logistic, alpha=0.01, hidden_layer_sizes=50, learning_rate_init=0.0001, score=-4.708770141890981, total=   2.8s
# [CV] activation=logistic, alpha=0.01, hidden_layer_sizes=50, learning_rate_init=0.0001
# [CV]  activation=logistic, alpha=0.01, hidden_layer_sizes=50, learning_rate_init=0.0001, score=-4.523843992174128, total=   3.1s
# [CV] activation=logistic, alpha=0.01, hidden_layer_sizes=50, learning_rate_init=0.0001
# [CV]  activation=logistic, alpha=0.01, hidden_layer_sizes=50, learning_rate_init=0.0001, score=-4.58489961497667, total=   2.7s
# [CV] activation=logistic, alpha=0.01, hidden_layer_sizes=100, learning_rate_init=0.01
# [CV]  activation=logistic, alpha=0.01, hidden_layer_sizes=100, learning_rate_init=0.01, score=-4.294898155281839, total=   0.0s
# [CV] activation=logistic, alpha=0.01, hidden_layer_sizes=100, learning_rate_init=0.01
# [CV]  activation=logistic, alpha=0.01, hidden_layer_sizes=100, learning_rate_init=0.01, score=-4.747212802323231, total=   0.0s
# [CV] activation=logistic, alpha=0.01, hidden_layer_sizes=100, learning_rate_init=0.01
# [CV]  activation=logistic, alpha=0.01, hidden_layer_sizes=100, learning_rate_init=0.01, score=-4.7343401167150425, total=   0.0s
# [CV] activation=logistic, alpha=0.01, hidden_layer_sizes=100, learning_rate_init=0.01
# [CV]  activation=logistic, alpha=0.01, hidden_layer_sizes=100, learning_rate_init=0.01, score=-4.540709191752323, total=   0.2s
# [CV] activation=logistic, alpha=0.01, hidden_layer_sizes=100, learning_rate_init=0.01
# [CV]  activation=logistic, alpha=0.01, hidden_layer_sizes=100, learning_rate_init=0.01, score=-4.607053605663752, total=   0.0s
# [CV] activation=logistic, alpha=0.01, hidden_layer_sizes=100, learning_rate_init=0.001
# [CV]  activation=logistic, alpha=0.01, hidden_layer_sizes=100, learning_rate_init=0.001, score=-4.279357065026483, total=   0.0s
# [CV] activation=logistic, alpha=0.01, hidden_layer_sizes=100, learning_rate_init=0.001
# [CV]  activation=logistic, alpha=0.01, hidden_layer_sizes=100, learning_rate_init=0.001, score=-4.717504349181194, total=   0.7s
# [CV] activation=logistic, alpha=0.01, hidden_layer_sizes=100, learning_rate_init=0.001
# [CV]  activation=logistic, alpha=0.01, hidden_layer_sizes=100, learning_rate_init=0.001, score=-4.739774697520276, total=   0.0s
# [CV] activation=logistic, alpha=0.01, hidden_layer_sizes=100, learning_rate_init=0.001
# [CV]  activation=logistic, alpha=0.01, hidden_layer_sizes=100, learning_rate_init=0.001, score=-4.522278434911474, total=   1.5s
# [CV] activation=logistic, alpha=0.01, hidden_layer_sizes=100, learning_rate_init=0.001
# [CV]  activation=logistic, alpha=0.01, hidden_layer_sizes=100, learning_rate_init=0.001, score=-4.583118483428138, total=   0.0s
# [CV] activation=logistic, alpha=0.01, hidden_layer_sizes=100, learning_rate_init=0.0001
# [CV]  activation=logistic, alpha=0.01, hidden_layer_sizes=100, learning_rate_init=0.0001, score=-4.268844022218007, total=   0.7s
# [CV] activation=logistic, alpha=0.01, hidden_layer_sizes=100, learning_rate_init=0.0001
# [CV]  activation=logistic, alpha=0.01, hidden_layer_sizes=100, learning_rate_init=0.0001, score=-4.7305934862963035, total=   1.4s
# [CV] activation=logistic, alpha=0.01, hidden_layer_sizes=100, learning_rate_init=0.0001
# [CV]  activation=logistic, alpha=0.01, hidden_layer_sizes=100, learning_rate_init=0.0001, score=-4.724976651040978, total=   1.3s
# [CV] activation=logistic, alpha=0.01, hidden_layer_sizes=100, learning_rate_init=0.0001
# [CV]  activation=logistic, alpha=0.01, hidden_layer_sizes=100, learning_rate_init=0.0001, score=-4.528174349650441, total=   1.5s
# [CV] activation=logistic, alpha=0.01, hidden_layer_sizes=100, learning_rate_init=0.0001
# [CV]  activation=logistic, alpha=0.01, hidden_layer_sizes=100, learning_rate_init=0.0001, score=-4.579794722420359, total=   2.3s
# [CV] activation=logistic, alpha=0.01, hidden_layer_sizes=150, learning_rate_init=0.01
# [CV]  activation=logistic, alpha=0.01, hidden_layer_sizes=150, learning_rate_init=0.01, score=-4.334298041606959, total=   0.1s
# [CV] activation=logistic, alpha=0.01, hidden_layer_sizes=150, learning_rate_init=0.01
# [CV]  activation=logistic, alpha=0.01, hidden_layer_sizes=150, learning_rate_init=0.01, score=-4.747801413002994, total=   0.1s
# [CV] activation=logistic, alpha=0.01, hidden_layer_sizes=150, learning_rate_init=0.01
# [CV]  activation=logistic, alpha=0.01, hidden_layer_sizes=150, learning_rate_init=0.01, score=-4.71443724725054, total=   0.1s
# [CV] activation=logistic, alpha=0.01, hidden_layer_sizes=150, learning_rate_init=0.01
# [CV]  activation=logistic, alpha=0.01, hidden_layer_sizes=150, learning_rate_init=0.01, score=-4.52529778427572, total=   0.2s
# [CV] activation=logistic, alpha=0.01, hidden_layer_sizes=150, learning_rate_init=0.01
# [CV]  activation=logistic, alpha=0.01, hidden_layer_sizes=150, learning_rate_init=0.01, score=-4.592891062548685, total=   0.0s
# [CV] activation=logistic, alpha=0.01, hidden_layer_sizes=150, learning_rate_init=0.001
# [CV]  activation=logistic, alpha=0.01, hidden_layer_sizes=150, learning_rate_init=0.001, score=-4.254681893510609, total=   0.6s
# [CV] activation=logistic, alpha=0.01, hidden_layer_sizes=150, learning_rate_init=0.001
# [CV]  activation=logistic, alpha=0.01, hidden_layer_sizes=150, learning_rate_init=0.001, score=-4.720124756619018, total=   0.3s
# [CV] activation=logistic, alpha=0.01, hidden_layer_sizes=150, learning_rate_init=0.001
# [CV]  activation=logistic, alpha=0.01, hidden_layer_sizes=150, learning_rate_init=0.001, score=-4.686954941000932, total=   0.5s
# [CV] activation=logistic, alpha=0.01, hidden_layer_sizes=150, learning_rate_init=0.001
# [CV]  activation=logistic, alpha=0.01, hidden_layer_sizes=150, learning_rate_init=0.001, score=-4.509464381844105, total=   0.7s
# [CV] activation=logistic, alpha=0.01, hidden_layer_sizes=150, learning_rate_init=0.001
# [CV]  activation=logistic, alpha=0.01, hidden_layer_sizes=150, learning_rate_init=0.001, score=-4.582535582084805, total=   0.6s
# [CV] activation=logistic, alpha=0.01, hidden_layer_sizes=150, learning_rate_init=0.0001
# [CV]  activation=logistic, alpha=0.01, hidden_layer_sizes=150, learning_rate_init=0.0001, score=-4.265742363273734, total=   0.8s
# [CV] activation=logistic, alpha=0.01, hidden_layer_sizes=150, learning_rate_init=0.0001
# [CV]  activation=logistic, alpha=0.01, hidden_layer_sizes=150, learning_rate_init=0.0001, score=-4.7302902635851245, total=   0.4s
# [CV] activation=logistic, alpha=0.01, hidden_layer_sizes=150, learning_rate_init=0.0001
# [CV]  activation=logistic, alpha=0.01, hidden_layer_sizes=150, learning_rate_init=0.0001, score=-4.7179768476945245, total=   0.5s
# [CV] activation=logistic, alpha=0.01, hidden_layer_sizes=150, learning_rate_init=0.0001
# [CV]  activation=logistic, alpha=0.01, hidden_layer_sizes=150, learning_rate_init=0.0001, score=-4.523863417853725, total=   1.6s
# [CV] activation=logistic, alpha=0.01, hidden_layer_sizes=150, learning_rate_init=0.0001
# [CV]  activation=logistic, alpha=0.01, hidden_layer_sizes=150, learning_rate_init=0.0001, score=-4.590612772832306, total=   0.7s
# [CV] activation=logistic, alpha=0.01, hidden_layer_sizes=200, learning_rate_init=0.01
# [CV]  activation=logistic, alpha=0.01, hidden_layer_sizes=200, learning_rate_init=0.01, score=-4.287863184462431, total=   0.1s
# [CV] activation=logistic, alpha=0.01, hidden_layer_sizes=200, learning_rate_init=0.01
# [CV]  activation=logistic, alpha=0.01, hidden_layer_sizes=200, learning_rate_init=0.01, score=-4.750145967777409, total=   0.1s
# [CV] activation=logistic, alpha=0.01, hidden_layer_sizes=200, learning_rate_init=0.01
# [CV]  activation=logistic, alpha=0.01, hidden_layer_sizes=200, learning_rate_init=0.01, score=-4.7291924836675845, total=   0.1s
# [CV] activation=logistic, alpha=0.01, hidden_layer_sizes=200, learning_rate_init=0.01
# [CV]  activation=logistic, alpha=0.01, hidden_layer_sizes=200, learning_rate_init=0.01, score=-4.539256263513215, total=   0.2s
# [CV] activation=logistic, alpha=0.01, hidden_layer_sizes=200, learning_rate_init=0.01
# [CV]  activation=logistic, alpha=0.01, hidden_layer_sizes=200, learning_rate_init=0.01, score=-4.581618111549832, total=   0.1s
# [CV] activation=logistic, alpha=0.01, hidden_layer_sizes=200, learning_rate_init=0.001
# [CV]  activation=logistic, alpha=0.01, hidden_layer_sizes=200, learning_rate_init=0.001, score=-4.264770665089715, total=   0.3s
# [CV] activation=logistic, alpha=0.01, hidden_layer_sizes=200, learning_rate_init=0.001
# [CV]  activation=logistic, alpha=0.01, hidden_layer_sizes=200, learning_rate_init=0.001, score=-4.728723557356169, total=   0.9s
# [CV] activation=logistic, alpha=0.01, hidden_layer_sizes=200, learning_rate_init=0.001
# [CV]  activation=logistic, alpha=0.01, hidden_layer_sizes=200, learning_rate_init=0.001, score=-4.672539393595912, total=   1.3s
# [CV] activation=logistic, alpha=0.01, hidden_layer_sizes=200, learning_rate_init=0.001
# [CV]  activation=logistic, alpha=0.01, hidden_layer_sizes=200, learning_rate_init=0.001, score=-4.515208409767876, total=   0.6s
# [CV] activation=logistic, alpha=0.01, hidden_layer_sizes=200, learning_rate_init=0.001
# [CV]  activation=logistic, alpha=0.01, hidden_layer_sizes=200, learning_rate_init=0.001, score=-4.573067386803025, total=   0.8s
# [CV] activation=logistic, alpha=0.01, hidden_layer_sizes=200, learning_rate_init=0.0001
# [CV]  activation=logistic, alpha=0.01, hidden_layer_sizes=200, learning_rate_init=0.0001, score=-4.272068358120831, total=   0.8s
# [CV] activation=logistic, alpha=0.01, hidden_layer_sizes=200, learning_rate_init=0.0001
# [CV]  activation=logistic, alpha=0.01, hidden_layer_sizes=200, learning_rate_init=0.0001, score=-4.740216789949413, total=   0.7s
# [CV] activation=logistic, alpha=0.01, hidden_layer_sizes=200, learning_rate_init=0.0001
# [CV]  activation=logistic, alpha=0.01, hidden_layer_sizes=200, learning_rate_init=0.0001, score=-4.729221540570647, total=   0.8s
# [CV] activation=logistic, alpha=0.01, hidden_layer_sizes=200, learning_rate_init=0.0001
# [CV]  activation=logistic, alpha=0.01, hidden_layer_sizes=200, learning_rate_init=0.0001, score=-4.533885905570667, total=   1.1s
# [CV] activation=logistic, alpha=0.01, hidden_layer_sizes=200, learning_rate_init=0.0001
# [CV]  activation=logistic, alpha=0.01, hidden_layer_sizes=200, learning_rate_init=0.0001, score=-4.5911557540436, total=   1.0s
# [CV] activation=logistic, alpha=0.001, hidden_layer_sizes=50, learning_rate_init=0.01
# [CV]  activation=logistic, alpha=0.001, hidden_layer_sizes=50, learning_rate_init=0.01, score=-4.2917793769756525, total=   0.0s
# [CV] activation=logistic, alpha=0.001, hidden_layer_sizes=50, learning_rate_init=0.01
# [CV]  activation=logistic, alpha=0.001, hidden_layer_sizes=50, learning_rate_init=0.01, score=-4.74728301686113, total=   0.0s
# [CV] activation=logistic, alpha=0.001, hidden_layer_sizes=50, learning_rate_init=0.01
# [CV]  activation=logistic, alpha=0.001, hidden_layer_sizes=50, learning_rate_init=0.01, score=-4.737708343976941, total=   0.0s
# [CV] activation=logistic, alpha=0.001, hidden_layer_sizes=50, learning_rate_init=0.01
# [CV]  activation=logistic, alpha=0.001, hidden_layer_sizes=50, learning_rate_init=0.01, score=-4.542874567134038, total=   0.0s
# [CV] activation=logistic, alpha=0.001, hidden_layer_sizes=50, learning_rate_init=0.01
# [CV]  activation=logistic, alpha=0.001, hidden_layer_sizes=50, learning_rate_init=0.01, score=-4.590876774254621, total=   0.0s
# [CV] activation=logistic, alpha=0.001, hidden_layer_sizes=50, learning_rate_init=0.001
# [CV]  activation=logistic, alpha=0.001, hidden_layer_sizes=50, learning_rate_init=0.001, score=-4.286132105855391, total=   0.1s
# [CV] activation=logistic, alpha=0.001, hidden_layer_sizes=50, learning_rate_init=0.001
# [CV]  activation=logistic, alpha=0.001, hidden_layer_sizes=50, learning_rate_init=0.001, score=-4.7314214550326295, total=   0.2s
# [CV] activation=logistic, alpha=0.001, hidden_layer_sizes=50, learning_rate_init=0.001
# [CV]  activation=logistic, alpha=0.001, hidden_layer_sizes=50, learning_rate_init=0.001, score=-4.683943461135387, total=   0.7s
# [CV] activation=logistic, alpha=0.001, hidden_layer_sizes=50, learning_rate_init=0.001
# [CV]  activation=logistic, alpha=0.001, hidden_layer_sizes=50, learning_rate_init=0.001, score=-4.491507152843239, total=   1.0s
# [CV] activation=logistic, alpha=0.001, hidden_layer_sizes=50, learning_rate_init=0.001
# [CV]  activation=logistic, alpha=0.001, hidden_layer_sizes=50, learning_rate_init=0.001, score=-4.568876676882588, total=   0.7s
# [CV] activation=logistic, alpha=0.001, hidden_layer_sizes=50, learning_rate_init=0.0001
# [CV]  activation=logistic, alpha=0.001, hidden_layer_sizes=50, learning_rate_init=0.0001, score=-4.251832525351923, total=   4.1s
# [CV] activation=logistic, alpha=0.001, hidden_layer_sizes=50, learning_rate_init=0.0001
# [CV]  activation=logistic, alpha=0.001, hidden_layer_sizes=50, learning_rate_init=0.0001, score=-4.733805144092725, total=   3.3s
# [CV] activation=logistic, alpha=0.001, hidden_layer_sizes=50, learning_rate_init=0.0001
# [CV]  activation=logistic, alpha=0.001, hidden_layer_sizes=50, learning_rate_init=0.0001, score=-4

# [CV] activation=relu, alpha=0.001, hidden_layer_sizes=200, learning_rate_init=0.001
# [CV]  activation=relu, alpha=0.001, hidden_layer_sizes=200, learning_rate_init=0.001, score=-4.738263762822775, total=   0.6s
# [CV] activation=relu, alpha=0.001, hidden_layer_sizes=200, learning_rate_init=0.001
# [CV]  activation=relu, alpha=0.001, hidden_layer_sizes=200, learning_rate_init=0.001, score=-4.591744804606194, total=   0.5s
# [CV] activation=relu, alpha=0.001, hidden_layer_sizes=200, learning_rate_init=0.001
# [CV]  activation=relu, alpha=0.001, hidden_layer_sizes=200, learning_rate_init=0.001, score=-4.687160777074741, total=   0.6s
# [CV] activation=relu, alpha=0.001, hidden_layer_sizes=200, learning_rate_init=0.0001
# [CV]  activation=relu, alpha=0.001, hidden_layer_sizes=200, learning_rate_init=0.0001, score=-4.282459504405308, total=   1.7s
# [CV] activation=relu, alpha=0.001, hidden_layer_sizes=200, learning_rate_init=0.0001
# [CV]  activation=relu, alpha=0.001, hidden_layer_sizes=200, learning_rate_init=0.0001, score=-4.757204868671722, total=   2.3s
# [CV] activation=relu, alpha=0.001, hidden_layer_sizes=200, learning_rate_init=0.0001
# [CV]  activation=relu, alpha=0.001, hidden_layer_sizes=200, learning_rate_init=0.0001, score=-4.6784213546780595, total=   2.0s
# [CV] activation=relu, alpha=0.001, hidden_layer_sizes=200, learning_rate_init=0.0001
# [CV]  activation=relu, alpha=0.001, hidden_layer_sizes=200, learning_rate_init=0.0001, score=-4.551519404207731, total=   1.3s
# [CV] activation=relu, alpha=0.001, hidden_layer_sizes=200, learning_rate_init=0.0001
# [CV]  activation=relu, alpha=0.001, hidden_layer_sizes=200, learning_rate_init=0.0001, score=-4.602876100887482, total=   3.4s
# [CV] activation=relu, alpha=0.0001, hidden_layer_sizes=50, learning_rate_init=0.01
# [CV]  activation=relu, alpha=0.0001, hidden_layer_sizes=50, learning_rate_init=0.01, score=-4.2990630327338675, total=   0.1s
# [CV] activation=relu, alpha=0.0001, hidden_layer_sizes=50, learning_rate_init=0.01
# [CV]  activation=relu, alpha=0.0001, hidden_layer_sizes=50, learning_rate_init=0.01, score=-4.729393495200955, total=   0.1s
# [CV] activation=relu, alpha=0.0001, hidden_layer_sizes=50, learning_rate_init=0.01
# [CV]  activation=relu, alpha=0.0001, hidden_layer_sizes=50, learning_rate_init=0.01, score=-4.67124979311287, total=   0.1s
# [CV] activation=relu, alpha=0.0001, hidden_layer_sizes=50, learning_rate_init=0.01
# [CV]  activation=relu, alpha=0.0001, hidden_layer_sizes=50, learning_rate_init=0.01, score=-4.560355747210304, total=   0.0s
# [CV] activation=relu, alpha=0.0001, hidden_layer_sizes=50, learning_rate_init=0.01
# [CV]  activation=relu, alpha=0.0001, hidden_layer_sizes=50, learning_rate_init=0.01, score=-4.640955337766726, total=   0.0s
# [CV] activation=relu, alpha=0.0001, hidden_layer_sizes=50, learning_rate_init=0.001
# [CV]  activation=relu, alpha=0.0001, hidden_layer_sizes=50, learning_rate_init=0.001, score=-4.2569538709087995, total=   0.3s
# [CV] activation=relu, alpha=0.0001, hidden_layer_sizes=50, learning_rate_init=0.001
# [CV]  activation=relu, alpha=0.0001, hidden_layer_sizes=50, learning_rate_init=0.001, score=-4.735239192458503, total=   0.2s
# [CV] activation=relu, alpha=0.0001, hidden_layer_sizes=50, learning_rate_init=0.001
# [CV]  activation=relu, alpha=0.0001, hidden_layer_sizes=50, learning_rate_init=0.001, score=-4.736797065280421, total=   0.3s
# [CV] activation=relu, alpha=0.0001, hidden_layer_sizes=50, learning_rate_init=0.001
# [CV]  activation=relu, alpha=0.0001, hidden_layer_sizes=50, learning_rate_init=0.001, score=-4.5562939690928355, total=   0.4s
# [CV] activation=relu, alpha=0.0001, hidden_layer_sizes=50, learning_rate_init=0.001
# [CV]  activation=relu, alpha=0.0001, hidden_layer_sizes=50, learning_rate_init=0.001, score=-4.586564277739911, total=   0.2s
# [CV] activation=relu, alpha=0.0001, hidden_layer_sizes=50, learning_rate_init=0.0001
# [CV]  activation=relu, alpha=0.0001, hidden_layer_sizes=50, learning_rate_init=0.0001, score=-4.249072255861089, total=   1.2s
# [CV] activation=relu, alpha=0.0001, hidden_layer_sizes=50, learning_rate_init=0.0001
# [CV]  activation=relu, alpha=0.0001, hidden_layer_sizes=50, learning_rate_init=0.0001, score=-4.762860369554222, total=   0.9s
# [CV] activation=relu, alpha=0.0001, hidden_layer_sizes=50, learning_rate_init=0.0001
# [CV]  activation=relu, alpha=0.0001, hidden_layer_sizes=50, learning_rate_init=0.0001, score=-4.727269705947226, total=   0.4s
# [CV] activation=relu, alpha=0.0001, hidden_layer_sizes=50, learning_rate_init=0.0001
# [CV]  activation=relu, alpha=0.0001, hidden_layer_sizes=50, learning_rate_init=0.0001, score=-4.513797111967802, total=   0.9s
# [CV] activation=relu, alpha=0.0001, hidden_layer_sizes=50, learning_rate_init=0.0001
# [CV]  activation=relu, alpha=0.0001, hidden_layer_sizes=50, learning_rate_init=0.0001, score=-4.577453974202755, total=   0.7s
# [CV] activation=relu, alpha=0.0001, hidden_layer_sizes=100, learning_rate_init=0.01
# [CV]  activation=relu, alpha=0.0001, hidden_layer_sizes=100, learning_rate_init=0.01, score=-4.308740651183861, total=   0.0s
# [CV] activation=relu, alpha=0.0001, hidden_layer_sizes=100, learning_rate_init=0.01
# [CV]  activation=relu, alpha=0.0001, hidden_layer_sizes=100, learning_rate_init=0.01, score=-4.745869647352118, total=   0.1s
# [CV] activation=relu, alpha=0.0001, hidden_layer_sizes=100, learning_rate_init=0.01
# [CV]  activation=relu, alpha=0.0001, hidden_layer_sizes=100, learning_rate_init=0.01, score=-4.728698827944991, total=   0.1s
# [CV] activation=relu, alpha=0.0001, hidden_layer_sizes=100, learning_rate_init=0.01
# [CV]  activation=relu, alpha=0.0001, hidden_layer_sizes=100, learning_rate_init=0.01, score=-4.553128394638347, total=   0.2s
# [CV] activation=relu, alpha=0.0001, hidden_layer_sizes=100, learning_rate_init=0.01
# [CV]  activation=relu, alpha=0.0001, hidden_layer_sizes=100, learning_rate_init=0.01, score=-4.56819514176451, total=   0.2s
# [CV] activation=relu, alpha=0.0001, hidden_layer_sizes=100, learning_rate_init=0.001
# [CV]  activation=relu, alpha=0.0001, hidden_layer_sizes=100, learning_rate_init=0.001, score=-4.356702628598547, total=   0.7s
# [CV] activation=relu, alpha=0.0001, hidden_layer_sizes=100, learning_rate_init=0.001
# [CV]  activation=relu, alpha=0.0001, hidden_layer_sizes=100, learning_rate_init=0.001, score=-4.71816508159679, total=   0.8s
# [CV] activation=relu, alpha=0.0001, hidden_layer_sizes=100, learning_rate_init=0.001
# [CV]  activation=relu, alpha=0.0001, hidden_layer_sizes=100, learning_rate_init=0.001, score=-4.679951077527758, total=   0.1s
# [CV] activation=relu, alpha=0.0001, hidden_layer_sizes=100, learning_rate_init=0.001
# [CV]  activation=relu, alpha=0.0001, hidden_layer_sizes=100, learning_rate_init=0.001, score=-4.554580207546181, total=   0.6s
# [CV] activation=relu, alpha=0.0001, hidden_layer_sizes=100, learning_rate_init=0.001
# [CV]  activation=relu, alpha=0.0001, hidden_layer_sizes=100, learning_rate_init=0.001, score=-4.594421143199278, total=   0.5s
# [CV] activation=relu, alpha=0.0001, hidden_layer_sizes=100, learning_rate_init=0.0001
# [CV]  activation=relu, alpha=0.0001, hidden_layer_sizes=100, learning_rate_init=0.0001, score=-4.299990670382556, total=   0.9s
# [CV] activation=relu, alpha=0.0001, hidden_layer_sizes=100, learning_rate_init=0.0001
# [CV]  activation=relu, alpha=0.0001, hidden_layer_sizes=100, learning_rate_init=0.0001, score=-4.712372337830885, total=   1.6s
# [CV] activation=relu, alpha=0.0001, hidden_layer_sizes=100, learning_rate_init=0.0001
# [CV]  activation=relu, alpha=0.0001, hidden_layer_sizes=100, learning_rate_init=0.0001, score=-4.77780096939661, total=   0.3s
# [CV] activation=relu, alpha=0.0001, hidden_layer_sizes=100, learning_rate_init=0.0001
# [CV]  activation=relu, alpha=0.0001, hidden_layer_sizes=100, learning_rate_init=0.0001, score=-4.455794613055118, total=   0.6s
# [CV] activation=relu, alpha=0.0001, hidden_layer_sizes=100, learning_rate_init=0.0001
# [CV]  activation=relu, alpha=0.0001, hidden_layer_sizes=100, learning_rate_init=0.0001, score=-4.568994634441164, total=   0.6s
# [CV] activation=relu, alpha=0.0001, hidden_layer_sizes=150, learning_rate_init=0.01
# [CV]  activation=relu, alpha=0.0001, hidden_layer_sizes=150, learning_rate_init=0.01, score=-4.326450556172038, total=   0.2s
# [CV] activation=relu, alpha=0.0001, hidden_layer_sizes=150, learning_rate_init=0.01
# [CV]  activation=relu, alpha=0.0001, hidden_layer_sizes=150, learning_rate_init=0.01, score=-4.754677925478807, total=   0.2s
# [CV] activation=relu, alpha=0.0001, hidden_layer_sizes=150, learning_rate_init=0.01
# [CV]  activation=relu, alpha=0.0001, hidden_layer_sizes=150, learning_rate_init=0.01, score=-4.73228427339339, total=   0.3s
# [CV] activation=relu, alpha=0.0001, hidden_layer_sizes=150, learning_rate_init=0.01
# [CV]  activation=relu, alpha=0.0001, hidden_layer_sizes=150, learning_rate_init=0.01, score=-4.525877726704619, total=   0.2s
# [CV] activation=relu, alpha=0.0001, hidden_layer_sizes=150, learning_rate_init=0.01
# [CV]  activation=relu, alpha=0.0001, hidden_layer_sizes=150, learning_rate_init=0.01, score=-4.579438441530315, total=   0.2s
# [CV] activation=relu, alpha=0.0001, hidden_layer_sizes=150, learning_rate_init=0.001
# [CV]  activation=relu, alpha=0.0001, hidden_layer_sizes=150, learning_rate_init=0.001, score=-4.3251313015886375, total=   0.2s
# [CV] activation=relu, alpha=0.0001, hidden_layer_sizes=150, learning_rate_init=0.001
# [CV]  activation=relu, alpha=0.0001, hidden_layer_sizes=150, learning_rate_init=0.001, score=-4.710230069871105, total=   0.4s
# [CV] activation=relu, alpha=0.0001, hidden_layer_sizes=150, learning_rate_init=0.001
# [CV]  activation=relu, alpha=0.0001, hidden_layer_sizes=150, learning_rate_init=0.001, score=-4.636868033469777, total=   0.2s
# [CV] activation=relu, alpha=0.0001, hidden_layer_sizes=150, learning_rate_init=0.001
# [CV]  activation=relu, alpha=0.0001, hidden_layer_sizes=150, learning_rate_init=0.001, score=-4.6221471961742795, total=   0.3s
# [CV] activation=relu, alpha=0.0001, hidden_layer_sizes=150, learning_rate_init=0.001
# [CV]  activation=relu, alpha=0.0001, hidden_layer_sizes=150, learning_rate_init=0.001, score=-4.7094616934023, total=   0.1s
# [CV] activation=relu, alpha=0.0001, hidden_layer_sizes=150, learning_rate_init=0.0001
# [CV]  activation=relu, alpha=0.0001, hidden_layer_sizes=150, learning_rate_init=0.0001, score=-4.328457849608435, total=   1.0s
# [CV] activation=relu, alpha=0.0001, hidden_layer_sizes=150, learning_rate_init=0.0001
# [CV]  activation=relu, alpha=0.0001, hidden_layer_sizes=150, learning_rate_init=0.0001, score=-4.772890971241218, total=   0.7s
# [CV] activation=relu, alpha=0.0001, hidden_layer_sizes=150, learning_rate_init=0.0001
# [CV]  activation=relu, alpha=0.0001, hidden_layer_sizes=150, learning_rate_init=0.0001, score=-4.656705494283006, total=   1.6s
# [CV] activation=relu, alpha=0.0001, hidden_layer_sizes=150, learning_rate_init=0.0001
# [CV]  activation=relu, alpha=0.0001, hidden_layer_sizes=150, learning_rate_init=0.0001, score=-4.579511209856989, total=   2.6s
# [CV] activation=relu, alpha=0.0001, hidden_layer_sizes=150, learning_rate_init=0.0001
# [CV]  activation=relu, alpha=0.0001, hidden_layer_sizes=150, learning_rate_init=0.0001, score=-4.6108772855894635, total=   2.1s
# [CV] activation=relu, alpha=0.0001, hidden_layer_sizes=200, learning_rate_init=0.01
# [CV]  activation=relu, alpha=0.0001, hidden_layer_sizes=200, learning_rate_init=0.01, score=-4.277189149087095, total=   0.2s
# [CV] activation=relu, alpha=0.0001, hidden_layer_sizes=200, learning_rate_init=0.01
# [CV]  activation=relu, alpha=0.0001, hidden_layer_sizes=200, learning_rate_init=0.01, score=-4.758655203940823, total=   0.4s
# [CV] activation=relu, alpha=0.0001, hidden_layer_sizes=200, learning_rate_init=0.01
# [CV]  activation=relu, alpha=0.0001, hidden_layer_sizes=200, learning_rate_init=0.01, score=-4.725606239747291, total=   0.4s
# [CV] activation=relu, alpha=0.0001, hidden_layer_sizes=200, learning_rate_init=0.01
# [CV]  activation=relu, alpha=0.0001, hidden_layer_sizes=200, learning_rate_init=0.01, score=-4.5193238031495255, total=   0.6s
# [CV] activation=relu, alpha=0.0001, hidden_layer_sizes=200, learning_rate_init=0.01
# [CV]  activation=relu, alpha=0.0001, hidden_layer_sizes=200, learning_rate_init=0.01, score=-4.584740492944895, total=   0.2s
# [CV] activation=relu, alpha=0.0001, hidden_layer_sizes=200, learning_rate_init=0.001
# [CV]  activation=relu, alpha=0.0001, hidden_layer_sizes=200, learning_rate_init=0.001, score=-4.4233671361729865, total=   0.4s
# [CV] activation=relu, alpha=0.0001, hidden_layer_sizes=200, learning_rate_init=0.001
# [CV]  activation=relu, alpha=0.0001, hidden_layer_sizes=200, learning_rate_init=0.001, score=-4.760571413844283, total=   0.6s
# [CV] activation=relu, alpha=0.0001, hidden_layer_sizes=200, learning_rate_init=0.001
# [CV]  activation=relu, alpha=0.0001, hidden_layer_sizes=200, learning_rate_init=0.001, score=-4.730758756807575, total=   0.6s
# [CV] activation=relu, alpha=0.0001, hidden_layer_sizes=200, learning_rate_init=0.001
# [CV]  activation=relu, alpha=0.0001, hidden_layer_sizes=200, learning_rate_init=0.001, score=-4.594475422434349, total=   0.6s
# [CV] activation=relu, alpha=0.0001, hidden_layer_sizes=200, learning_rate_init=0.001
# [CV]  activation=relu, alpha=0.0001, hidden_layer_sizes=200, learning_rate_init=0.001, score=-4.682710874777702, total=   0.7s
# [CV] activation=relu, alpha=0.0001, hidden_layer_sizes=200, learning_rate_init=0.0001
# [CV]  activation=relu, alpha=0.0001, hidden_layer_sizes=200, learning_rate_init=0.0001, score=-4.282452661441554, total=   1.7s
# [CV] activation=relu, alpha=0.0001, hidden_layer_sizes=200, learning_rate_init=0.0001
# [CV]  activation=relu, alpha=0.0001, hidden_layer_sizes=200, learning_rate_init=0.0001, score=-4.75684544702252, total=   2.1s
# [CV] activation=relu, alpha=0.0001, hidden_layer_sizes=200, learning_rate_init=0.0001
# [CV]  activation=relu, alpha=0.0001, hidden_layer_sizes=200, learning_rate_init=0.0001, score=-4.678526130377845, total=   1.9s
# [CV] activation=relu, alpha=0.0001, hidden_layer_sizes=200, learning_rate_init=0.0001
# [CV]  activation=relu, alpha=0.0001, hidden_layer_sizes=200, learning_rate_init=0.0001, score=-4.551354455097055, total=   1.2s
# [CV] activation=relu, alpha=0.0001, hidden_layer_sizes=200, learning_rate_init=0.0001
# [CV]  activation=relu, alpha=0.0001, hidden_layer_sizes=200, learning_rate_init=0.0001, score=-4.604295127095561, total=   3.3s
# [Parallel(n_jobs=1)]: Done 360 out of 360 | elapsed:  4.8min finished
# GridSearchCV(cv=KFold(n_splits=5, random_state=42, shuffle=True),
#        error_score='raise',
#        estimator=MLPRegressor(activation='relu', alpha=0.0001, batch_size='auto', beta_1=0.9,
#        beta_2=0.999, early_stopping=False, epsilon=1e-08,
#        hidden_layer_sizes=(100,), learning_rate='constant',
#        learning_rate_init=0.001, max_iter=1000, momentum=0.9,
#        nesterovs_momentum=True, power_t=0.5, random_state=42, shuffle=True,
#        solver='adam', tol=0.0001, validation_fraction=0.1, verbose=False,
#        warm_start=False),
#        fit_params=None, iid=True, n_jobs=1,
#        param_grid={'hidden_layer_sizes': [50, 100, 150, 200], 'activation': ['logistic', 'relu'], 'learning_rate_init': [0.01, 0.001, 0.0001], 'alpha': [0.01, 0.001, 0.0001]},
#        pre_dispatch='2*n_jobs', refit=True, return_train_score='warn',
#        scoring='neg_mean_absolute_error', verbose=10)

# %%
mlp_1_GS.best_params_
# Out:
# {'activation': 'logistic',
#  'alpha': 0.0001,
#  'hidden_layer_sizes': 200,
#  'learning_rate_init': 0.001}

# %%
mlp_1_mod = MLPRegressor(activation='logistic', alpha=0.0001, batch_size='auto', beta_1=0.9,
       beta_2=0.999, early_stopping=False, epsilon=1e-08,
       hidden_layer_sizes=(200,), learning_rate='constant',
       learning_rate_init=0.001, max_iter=1000, momentum=0.9,
       nesterovs_momentum=True, power_t=0.5, random_state=seed,
       shuffle=True, solver='sgd', tol=0.0001, validation_fraction=0.1,
       verbose=False, warm_start=False)

# %%
cross_val(X_1, y_1, mlp_1_mod)
# Out:
# MAE: 4.5603 (0.1753)
# MSE: 30.9520 (2.1276)
# -----------------------------------------

# %%
mlp_1_mod.fit(X_1, y_1)
# Out:
# MLPRegressor(activation='logistic', alpha=0.0001, batch_size='auto',
#        beta_1=0.9, beta_2=0.999, early_stopping=False, epsilon=1e-08,
#        hidden_layer_sizes=(200,), learning_rate='constant',
#        learning_rate_init=0.001, max_iter=1000, momentum=0.9,
#        nesterovs_momentum=True, power_t=0.5, random_state=42, shuffle=True,
#        solver='sgd', tol=0.0001, validation_fraction=0.1, verbose=False,
#        warm_start=False)

# %%
show_preds(mlp_1_mod, X_1, y_1, df_1_all)

# %% [markdown]
# ## Position 2

# %%
# Create an estimator object with the estimator and parameter candidates.
kfold = KFold(n_splits=5, random_state=seed, shuffle = True)
mlp_2_GS = GridSearchCV(estimator=base_MLP, param_grid=param_grid, verbose=10,
                        scoring='neg_mean_absolute_error', cv=kfold)

# %%
mlp_2_GS.fit(X_2, y_2)
# Out:
# Fitting 5 folds for each of 72 candidates, totalling 360 fits
# [CV] activation=logistic, alpha=0.01, hidden_layer_sizes=50, learning_rate_init=0.01
# [CV]  activation=logistic, alpha=0.01, hidden_layer_sizes=50, learning_rate_init=0.01, score=-3.3405024313964846, total=   0.1s
# [CV] activation=logistic, alpha=0.01, hidden_layer_sizes=50, learning_rate_init=0.01
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.1s remaining:    0.0s
# [CV]  activation=logistic, alpha=0.01, hidden_layer_sizes=50, learning_rate_init=0.01, score=-3.1166141187647294, total=   0.6s
# [CV] activation=logistic, alpha=0.01, hidden_layer_sizes=50, learning_rate_init=0.01
# [CV]  activation=logistic, alpha=0.01, hidden_layer_sizes=50, learning_rate_init=0.01, score=-3
total=   0.4s
# [CV] activation=relu, alpha=0.0001, hidden_layer_sizes=100, learning_rate_init=0.01
# [CV]  activation=relu, alpha=0.0001, hidden_layer_sizes=100, learning_rate_init=0.01, score=-3.1476454289251037, total=   0.3s
# [CV] activation=relu, alpha=0.0001, hidden_layer_sizes=100, learning_rate_init=0.01
# [CV]  activation=relu, alpha=0.0001, hidden_layer_sizes=100, learning_rate_init=0.01, score=-3.20488871464395, total=   0.4s
# [CV] activation=relu, alpha=0.0001, hidden_layer_sizes=100, learning_rate_init=0.01
# [CV]  activation=relu, alpha=0.0001, hidden_layer_sizes=100, learning_rate_init=0.01, score=-3.4506684092932214, total=   0.4s
# [CV] activation=relu, alpha=0.0001, hidden_layer_sizes=100, learning_rate_init=0.001
# [CV]  activation=relu, alpha=0.0001, hidden_layer_sizes=100, learning_rate_init=0.001, score=-3.3964662179120473, total=   0.9s
# [CV] activation=relu, alpha=0.0001, hidden_layer_sizes=100, learning_rate_init=0.001
# [CV]  activation=relu, alpha=0.0001, hidden_layer_sizes=100, learning_rate_init=0.001, score=-3.1686766509734814, total=   2.5s
# [CV] activation=relu, alpha=0.0001, hidden_layer_sizes=100, learning_rate_init=0.001
# [CV]  activation=relu, alpha=0.0001, hidden_layer_sizes=100, learning_rate_init=0.001, score=-3.290400655973005, total=   3.3s
# [CV] activation=relu, alpha=0.0001, hidden_layer_sizes=100, learning_rate_init=0.001
# [CV]  activation=relu, alpha=0.0001, hidden_layer_sizes=100, learning_rate_init=0.001, score=-3.2779548103028926, total=   1.6s
# [CV] activation=relu, alpha=0.0001, hidden_layer_sizes=100, learning_rate_init=0.001
# [CV]  activation=relu, alpha=0.0001, hidden_layer_sizes=100, learning_rate_init=0.001, score=-3.384310620706448, total=   1.4s
# [CV] activation=relu, alpha=0.0001, hidden_layer_sizes=100, learning_rate_init=0.0001
# [CV]  activation=relu, alpha=0.0001, hidden_layer_sizes=100, learning_rate_init=0.0001, score=-3.2979781634779144, total=   5.5s
# [CV] activation=relu, alpha=0.0001, hidden_layer_sizes=100, learning_rate_init=0.0001
# [CV]  activation=relu, alpha=0.0001, hidden_layer_sizes=100, learning_rate_init=0.0001, score=-3.0280537410697206, total=   5.8s
# [CV] activation=relu, alpha=0.0001, hidden_layer_sizes=100, learning_rate_init=0.0001
# [CV]  activation=relu, alpha=0.0001, hidden_layer_sizes=100, learning_rate_init=0.0001, score=-3.156302773998856, total=  12.2s
# [CV] activation=relu, alpha=0.0001, hidden_layer_sizes=100, learning_rate_init=0.0001
# [CV]  activation=relu, alpha=0.0001, hidden_layer_sizes=100, learning_rate_init=0.0001, score=-3.2575115224234694, total=   6.4s
# [CV] activation=relu, alpha=0.0001, hidden_layer_sizes=100, learning_rate_init=0.0001
# [CV]  activation=relu, alpha=0.0001, hidden_layer_sizes=100, learning_rate_init=0.0001, score=-3.36699315616474, total=   5.4s
# [CV] activation=relu, alpha=0.0001, hidden_layer_sizes=150, learning_rate_init=0.01
# [CV]  activation=relu, alpha=0.0001, hidden_layer_sizes=150, learning_rate_init=0.01, score=-3.2194092051692795, total=   1.1s
# [CV] activation=relu, alpha=0.0001, hidden_layer_sizes=150, learning_rate_init=0.01
# [CV]  activation=relu, alpha=0.0001, hidden_layer_sizes=150, learning_rate_init=0.01, score=-3.1441478679794126, total=   0.3s
# [CV] activation=relu, alpha=0.0001, hidden_layer_sizes=150, learning_rate_init=0.01
# [CV]  activation=relu, alpha=0.0001, hidden_layer_sizes=150, learning_rate_init=0.01, score=-3.164829707830114, total=   0.9s
# [CV] activation=relu, alpha=0.0001, hidden_layer_sizes=150, learning_rate_init=0.01
# [CV]  activation=relu, alpha=0.0001, hidden_layer_sizes=150, learning_rate_init=0.01, score=-3.2578254807056144, total=   0.5s
# [CV] activation=relu, alpha=0.0001, hidden_layer_sizes=150, learning_rate_init=0.01
# [CV]  activation=relu, alpha=0.0001, hidden_layer_sizes=150, learning_rate_init=0.01, score=-3.4236841344242994, total=   0.8s
# [CV] activation=relu, alpha=0.0001, hidden_layer_sizes=150, learning_rate_init=0.001
# [CV]  activation=relu, alpha=0.0001, hidden_layer_sizes=150, learning_rate_init=0.001, score=-3.389174818074194, total=   2.7s
# [CV] activation=relu, alpha=0.0001, hidden_layer_sizes=150, learning_rate_init=0.001
# [CV]  activation=relu, alpha=0.0001, hidden_layer_sizes=150, learning_rate_init=0.001, score=-3.049985663536072, total=   1.5s
# [CV] activation=relu, alpha=0.0001, hidden_layer_sizes=150, learning_rate_init=0.001
# [CV]  activation=relu, alpha=0.0001, hidden_layer_sizes=150, learning_rate_init=0.001, score=-3.204863106368085, total=   1.6s
# [CV] activation=relu, alpha=0.0001, hidden_layer_sizes=150, learning_rate_init=0.001
# [CV]  activation=relu, alpha=0.0001, hidden_layer_sizes=150, learning_rate_init=0.001, score=-3.3097507270934616, total=   0.6s
# [CV] activation=relu, alpha=0.0001, hidden_layer_sizes=150, learning_rate_init=0.001
# [CV]  activation=relu, alpha=0.0001, hidden_layer_sizes=150, learning_rate_init=0.001, score=-3.4206518178237233, total=   2.6s
# [CV] activation=relu, alpha=0.0001, hidden_layer_sizes=150, learning_rate_init=0.0001
# [CV]  activation=relu, alpha=0.0001, hidden_layer_sizes=150, learning_rate_init=0.0001, score=-3.2688570384063618, total=   3.1s
# [CV] activation=relu, alpha=0.0001, hidden_layer_sizes=150, learning_rate_init=0.0001
# [CV]  activation=relu, alpha=0.0001, hidden_layer_sizes=150, learning_rate_init=0.0001, score=-3.0333121176048268, total=   5.4s
# [CV] activation=relu, alpha=0.0001, hidden_layer_sizes=150, learning_rate_init=0.0001
# [CV]  activation=relu, alpha=0.0001, hidden_layer_sizes=150, learning_rate_init=0.0001, score=-3.1420336963460085, total=   3.0s
# [CV] activation=relu, alpha=0.0001, hidden_layer_sizes=150, learning_rate_init=0.0001
# [CV]  activation=relu, alpha=0.0001, hidden_layer_sizes=150, learning_rate_init=0.0001, score=-3.2821958717194866, total=   1.9s
# [CV] activation=relu, alpha=0.0001, hidden_layer_sizes=150, learning_rate_init=0.0001
# [CV]  activation=relu, alpha=0.0001, hidden_layer_sizes=150, learning_rate_init=0.0001, score=-3.3759324275777427, total=   5.2s
# [CV] activation=relu, alpha=0.0001, hidden_layer_sizes=200, learning_rate_init=0.01
# [CV]  activation=relu, alpha=0.0001, hidden_layer_sizes=200, learning_rate_init=0.01, score=-3.3071998785742087, total=   1.0s
# [CV] activation=relu, alpha=0.0001, hidden_layer_sizes=200, learning_rate_init=0.01
# [CV]  activation=relu, alpha=0.0001, hidden_layer_sizes=200, learning_rate_init=0.01, score=-3.1042619443831483, total=   0.5s
# [CV] activation=relu, alpha=0.0001, hidden_layer_sizes=200, learning_rate_init=0.01
# [CV]  activation=relu, alpha=0.0001, hidden_layer_sizes=200, learning_rate_init=0.01, score=-3.1154449521548324, total=   0.8s
# [CV] activation=relu, alpha=0.0001, hidden_layer_sizes=200, learning_rate_init=0.01
# [CV]  activation=relu, alpha=0.0001, hidden_layer_sizes=200, learning_rate_init=0.01, score=-3.4017021937455256, total=   0.5s
# [CV] activation=relu, alpha=0.0001, hidden_layer_sizes=200, learning_rate_init=0.01
# [CV]  activation=relu, alpha=0.0001, hidden_layer_sizes=200, learning_rate_init=0.01, score=-3.397672676648147, total=   0.9s
# [CV] activation=relu, alpha=0.0001, hidden_layer_sizes=200, learning_rate_init=0.001
# [CV]  activation=relu, alpha=0.0001, hidden_layer_sizes=200, learning_rate_init=0.001, score=-3.1993295669713695, total=   1.5s
# [CV] activation=relu, alpha=0.0001, hidden_layer_sizes=200, learning_rate_init=0.001
# [CV]  activation=relu, alpha=0.0001, hidden_layer_sizes=200, learning_rate_init=0.001, score=-3.0173599744848487, total=   2.0s
# [CV] activation=relu, alpha=0.0001, hidden_layer_sizes=200, learning_rate_init=0.001
# [CV]  activation=relu, alpha=0.0001, hidden_layer_sizes=200, learning_rate_init=0.001, score=-3.182545736044313, total=   1.7s
# [CV] activation=relu, alpha=0.0001, hidden_layer_sizes=200, learning_rate_init=0.001
# [CV]  activation=relu, alpha=0.0001, hidden_layer_sizes=200, learning_rate_init=0.001, score=-3.4761328552977777, total=   3.6s
# [CV] activation=relu, alpha=0.0001, hidden_layer_sizes=200, learning_rate_init=0.001
# [CV]  activation=relu, alpha=0.0001, hidden_layer_sizes=200, learning_rate_init=0.001, score=-3.464915294958024, total=   3.1s
# [CV] activation=relu, alpha=0.0001, hidden_layer_sizes=200, learning_rate_init=0.0001
# [CV]  activation=relu, alpha=0.0001, hidden_layer_sizes=200, learning_rate_init=0.0001, score=-3.208013333574921, total=   8.2s
# [CV] activation=relu, alpha=0.0001, hidden_layer_sizes=200, learning_rate_init=0.0001
# [CV]  activation=relu, alpha=0.0001, hidden_layer_sizes=200, learning_rate_init=0.0001, score=-3.0629451176517235, total=   2.6s
# [CV] activation=relu, alpha=0.0001, hidden_layer_sizes=200, learning_rate_init=0.0001
# [CV]  activation=relu, alpha=0.0001, hidden_layer_sizes=200, learning_rate_init=0.0001, score=-3.1433746642173754, total=   5.5s
# [CV] activation=relu, alpha=0.0001, hidden_layer_sizes=200, learning_rate_init=0.0001
# [CV]  activation=relu, alpha=0.0001, hidden_layer_sizes=200, learning_rate_init=0.0001, score=-3.219178272780428, total=   5.1s
# [CV] activation=relu, alpha=0.0001, hidden_layer_sizes=200, learning_rate_init=0.0001
# [CV]  activation=relu, alpha=0.0001, hidden_layer_sizes=200, learning_rate_init=0.0001, score=-3.3852764555493997, total=   6.3s
# [Parallel(n_jobs=1)]: Done 360 out of 360 | elapsed: 17.9min finished
# GridSearchCV(cv=KFold(n_splits=5, random_state=42, shuffle=True),
#        error_score='raise',
#        estimator=MLPRegressor(activation='relu', alpha=0.0001, batch_size='auto', beta_1=0.9,
#        beta_2=0.999, early_stopping=False, epsilon=1e-08,
#        hidden_layer_sizes=(100,), learning_rate='constant',
#        learning_rate_init=0.001, max_iter=1000, momentum=0.9,
#        nesterovs_momentum=True, power_t=0.5, random_state=42, shuffle=True,
#        solver='adam', tol=0.0001, validation_fraction=0.1, verbose=False,
#        warm_start=False),
#        fit_params=None, iid=True, n_jobs=1,
#        param_grid={'hidden_layer_sizes': [50, 100, 150, 200], 'activation': ['logistic', 'relu'], 'learning_rate_init': [0.01, 0.001, 0.0001], 'alpha': [0.01, 0.001, 0.0001]},
#        pre_dispatch='2*n_jobs', refit=True, return_train_score='warn',
#        scoring='neg_mean_absolute_error', verbose=10)

# %%
mlp_2_GS.best_params_
# Out:
# {'activation': 'relu',
#  'alpha': 0.01,
#  'hidden_layer_sizes': 200,
#  'learning_rate_init': 0.0001}

# %%
mlp_2_mod = MLPRegressor(activation='relu', alpha=0.01, batch_size='auto', beta_1=0.9,
       beta_2=0.999, early_stopping=False, epsilon=1e-08,
       hidden_layer_sizes=(200,), learning_rate='constant',
       learning_rate_init=0.0001, max_iter=1000, momentum=0.9,
       nesterovs_momentum=True, power_t=0.5, random_state=42,
       shuffle=True, solver='adam', tol=0.0001, validation_fraction=0.1,
       verbose=False, warm_start=False)

# %%
cross_val(X_2, y_2, mlp_2_mod)
# Out:
# MAE: 3.2033 (0.1064)
# MSE: 16.6079 (1.4895)
# -----------------------------------------

# %%
mlp_2_mod.fit(X_2, y_2)
# Out:
# MLPRegressor(activation='relu', alpha=0.01, batch_size='auto', beta_1=0.9,
#        beta_2=0.999, early_stopping=False, epsilon=1e-08,
#        hidden_layer_sizes=(200,), learning_rate='constant',
#        learning_rate_init=0.0001, max_iter=1000, momentum=0.9,
#        nesterovs_momentum=True, power_t=0.5, random_state=42, shuffle=True,
#        solver='adam', tol=0.0001, validation_fraction=0.1, verbose=False,
#        warm_start=False)

# %%
show_preds(mlp_2_mod, X_2, y_2, df_2_all)

# %% [markdown]
# ## Position 3

# %%
# Create an estimator object with the estimator and parameter candidates.
kfold = KFold(n_splits=5, random_state=seed, shuffle = True)
mlp_3_GS = GridSearchCV(estimator=base_MLP, param_grid=param_grid, verbose=10,
                        scoring='neg_mean_absolute_error', cv=kfold)

# %%
mlp_3_GS.fit(X_3, y_3)
# Out:
# Fitting 5 folds for each of 72 candidates, totalling 360 fits
# [CV] activation=logistic, alpha=0.01, hidden_layer_sizes=50, learning_rate_init=0.01
# [CV]  activation=logistic, alpha=0.01, hidden_layer_sizes=50, learning_rate_init=0.01, score=-3.240045593721887, total=   0.1s
# [CV] activation=logistic, alpha=0.01, hidden_layer_sizes=50, learning_rate_init=0.01
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.1s remaining:    0.0s
# [CV]  activation=logistic, alpha=0.01, hidden_layer_sizes=50, learning_rate_init=0.01, score=-3.1897813556123857, total=   0.8s
# [CV] activation=logistic, alpha=0.01, hidden_layer_sizes=50, learning_rate_init=0.01
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    1.0s remaining:    0.0s
# [CV]  activation=logistic, alpha=0.01, hidden_layer_sizes=50, learning_rate_init=0.01, score=-3.0827972149582297, total=   0.1s
# [CV] activation=logistic, alpha=0.01, hidden_layer_sizes=50, learning_rate_init=0.01
# [CV]  activation=logistic, alpha=0.01, hidden_layer_sizes=50, learning_rate_init=0.01, score=-3.102634109630795, total=   0.1s
# [CV] activation=logistic, alpha=0.01, hidden_layer_sizes=50, learning_rate_init=0.01
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    1.3s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    1.4s remaining:    0.0s
# [CV]  activation=logistic, alpha=0.01, hidden_layer_sizes=50, learning_rate_init=0.01, score=-3.015771114677474, total=   0.1s
# [CV] activation=logistic, alpha=0.01, hidden_layer_sizes=50, learning_rate_init=0.001
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    1.7s remaining:    0.0s
# [CV]  activation=logistic, alpha=0.01, hidden_layer_sizes=50, learning_rate_init=0.001, score=-3.1100039958979235, total=   1.3s
# [CV] activation=logistic, alpha=0.01, hidden_layer_sizes=50, learning_rate_init=0.001
# [Parallel(n_jobs=1)]: Done   6 out of   6 | elapsed:    3.1s remaining:    0.0s
# [CV]  activation=logistic, alpha=0.01, hidden_layer_sizes=50, learning_rate_init=0.001, score=-3.1636622408887525, total=   1.6s
# [CV] activation=logistic, alpha=0.01, hidden_layer_sizes=50, learning_rate_init=0.001
# [Parallel(n_jobs=1)]: Done   7 out of   7 | elapsed:    4.8s remaining:    0.0s
# [CV]  activation=logistic, alpha=0.01, hidden_layer_sizes=50, learning_rate_init=0.001, score=-3.0200650790036256, total=   1.6s
# [CV] activation=logistic, alpha=0.01, hidden_layer_sizes=50, learning_rate_init=0.001
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed:    6.5s remaining:    0.0s
# [CV]  activation=logistic, alpha=0.01, hidden_layer_sizes=50, learning_rate_init=0.001, score=-3.106517546323152, total=   1.3s
# [CV] activation=logistic, alpha=0.01, hidden_layer_sizes=50, learning_rate_init=0.001
# [Parallel(n_jobs=1)]: Done   9 out of   9 | elapsed:    7.9s remaining:    0.0s
# [CV]  activation=logistic, alpha=0.01, hidden_layer_sizes=50, learning_rate_init=0.001, score=-2.8479951135154637, total=   1.9s
# [CV] activation=logistic, alpha=0.01, hidden_layer_sizes=50, learning_rate_init=0.0001
# [CV]  activation=logistic, alpha=0.01, hidden_layer_sizes=50, learning_rate_init=0.0001, score=-3.112147967809991, total=   8.2s
# [CV] activation=logistic, alpha=0.01, hidden_layer_sizes=50, learning_rate_init=0.0001
# [CV]  activation=logistic, alpha=0.01, hidden_layer_sizes=50, learning_rate_init=0.0001, score=-3.1779201301702127, total=   8.1s
# [CV] activation=logistic, alpha=0.01, hidden_layer_sizes=50, learning_rate_init=0.0001
# [CV]  activation=logistic, alpha=0.01, hidden_layer_sizes=50, learning_rate_init=0.0001, score=-3.0449768838483817, total=   5.7s
# [CV] activation=logistic, alpha=0.01, hidden_layer_sizes=50, learning_rate_init=0.0001
# [CV]  activation=logistic, alpha=0.01, hidden_layer_sizes=50, learning_rate_init=0.0001, score=-3.0856222843946566, total=   8.8s
# [CV] activation=logistic, alpha=0.01, hidden_layer_sizes=50, learning_rate_init=0.0001
# [CV]  activation=logistic, alpha=0.01, hidden_layer_sizes=50, learning_rate_init=0.0001, score=-2.8768361102796884, total=   8.0s
# [CV] activation=logistic, alpha=0.01, hidden_layer_sizes=100, learning_rate_init=0.01
# [CV]  activation=logistic, alpha=0.01, hidden_layer_sizes=100, learning_rate_init=0.01, score=-3.223779210119873, total=   0.1s
# [CV] activation=logistic, alpha=0.01, hidden_layer_sizes=100, learning_rate_init=0.01
# [CV]  activation=logistic, alpha=0.01, hidden_layer_sizes=100, learning_rate_init=0.01, score=-3.1638019583451413, total=   0.8s
# [CV] activation=logistic, alpha=0.01, hidden_layer_sizes=100, learning_rate_init=0.01
# [CV]  activation=logistic, alpha=0.01, hidden_layer_sizes=100, learning_rate_init=0.01, score=-3.1050468096736674, total=   0.1s
# [CV] activation=logistic, alpha=0.01, hidden_layer_sizes=100, learning_rate_init=0.01
# [CV]  activation=logistic, alpha=0.01, hidden_layer_sizes=100, learning_rate_init=0.01, score=-3.086514799449609, total=   0.8s
# [CV] activation=logistic, alpha=0.01, hidden_layer_sizes=100, learning_rate_init=0.01
# [CV]  activation=logistic, alpha=0.01, hidden_layer_sizes=100, learning_rate_init=0.01, score=-3.033670416365962, total=   0.2s
# [CV] activation=logistic, alpha=0.01, hidden_layer_sizes=100, learning_rate_init=0.001
# [CV]  activation=logistic, alpha=0.01, hidden_layer_sizes=100, learning_rate_init=0.001, score=-3.1026527901116694, total=   1.7s
# [CV] activation=logistic, alpha=0.01, hidden_layer_sizes=100, learning_rate_init=0.001
# [CV]  activation=logistic, alpha=0.01, hidden_layer_sizes=100, learning_rate_init=0.001, score=-3
4s
# [CV] activation=relu, alpha=0.0001, hidden_layer_sizes=150, learning_rate_init=0.001
# [CV]  activation=relu, alpha=0.0001, hidden_layer_sizes=150, learning_rate_init=0.001, score=-3.0857013119900127, total=   2.1s
# [CV] activation=relu, alpha=0.0001, hidden_layer_sizes=150, learning_rate_init=0.001
# [CV]  activation=relu, alpha=0.0001, hidden_layer_sizes=150, learning_rate_init=0.001, score=-3.3673501766922476, total=   2.6s
# [CV] activation=relu, alpha=0.0001, hidden_layer_sizes=150, learning_rate_init=0.001
# [CV]  activation=relu, alpha=0.0001, hidden_layer_sizes=150, learning_rate_init=0.001, score=-3.170491732932729, total=   3.4s
# [CV] activation=relu, alpha=0.0001, hidden_layer_sizes=150, learning_rate_init=0.001
# [CV]  activation=relu, alpha=0.0001, hidden_layer_sizes=150, learning_rate_init=0.001, score=-3.0681733871112846, total=   2.1s
# [CV] activation=relu, alpha=0.0001, hidden_layer_sizes=150, learning_rate_init=0.001
# [CV]  activation=relu, alpha=0.0001, hidden_layer_sizes=150, learning_rate_init=0.001, score=-2.8825734699319274, total=   2.9s
# [CV] activation=relu, alpha=0.0001, hidden_layer_sizes=150, learning_rate_init=0.0001
# [CV]  activation=relu, alpha=0.0001, hidden_layer_sizes=150, learning_rate_init=0.0001, score=-3.128484316451957, total=   3.2s
# [CV] activation=relu, alpha=0.0001, hidden_layer_sizes=150, learning_rate_init=0.0001
# [CV]  activation=relu, alpha=0.0001, hidden_layer_sizes=150, learning_rate_init=0.0001, score=-3.1820779365533114, total=   5.5s
# [CV] activation=relu, alpha=0.0001, hidden_layer_sizes=150, learning_rate_init=0.0001
# [CV]  activation=relu, alpha=0.0001, hidden_layer_sizes=150, learning_rate_init=0.0001, score=-3.0100720838123616, total=   5.4s
# [CV] activation=relu, alpha=0.0001, hidden_layer_sizes=150, learning_rate_init=0.0001
# [CV]  activation=relu, alpha=0.0001, hidden_layer_sizes=150, learning_rate_init=0.0001, score=-3.0484550053063884, total=   3.7s
# [CV] activation=relu, alpha=0.0001, hidden_layer_sizes=150, learning_rate_init=0.0001
# [CV]  activation=relu, alpha=0.0001, hidden_layer_sizes=150, learning_rate_init=0.0001, score=-2.8338619997981964, total=   6.2s
# [CV] activation=relu, alpha=0.0001, hidden_layer_sizes=200, learning_rate_init=0.01
# [CV]  activation=relu, alpha=0.0001, hidden_layer_sizes=200, learning_rate_init=0.01, score=-3.133455882675805, total=   1.0s
# [CV] activation=relu, alpha=0.0001, hidden_layer_sizes=200, learning_rate_init=0.01
# [CV]  activation=relu, alpha=0.0001, hidden_layer_sizes=200, learning_rate_init=0.01, score=-3.1377745499384875, total=   1.0s
# [CV] activation=relu, alpha=0.0001, hidden_layer_sizes=200, learning_rate_init=0.01
# [CV]  activation=relu, alpha=0.0001, hidden_layer_sizes=200, learning_rate_init=0.01, score=-3.0230707191973925, total=   1.0s
# [CV] activation=relu, alpha=0.0001, hidden_layer_sizes=200, learning_rate_init=0.01
# [CV]  activation=relu, alpha=0.0001, hidden_layer_sizes=200, learning_rate_init=0.01, score=-3.057486294957683, total=   0.7s
# [CV] activation=relu, alpha=0.0001, hidden_layer_sizes=200, learning_rate_init=0.01
# [CV]  activation=relu, alpha=0.0001, hidden_layer_sizes=200, learning_rate_init=0.01, score=-2.8580047265921973, total=   0.4s
# [CV] activation=relu, alpha=0.0001, hidden_layer_sizes=200, learning_rate_init=0.001
# [CV]  activation=relu, alpha=0.0001, hidden_layer_sizes=200, learning_rate_init=0.001, score=-3.0818970866312547, total=   2.9s
# [CV] activation=relu, alpha=0.0001, hidden_layer_sizes=200, learning_rate_init=0.001
# [CV]  activation=relu, alpha=0.0001, hidden_layer_sizes=200, learning_rate_init=0.001, score=-3.460157469385195, total=   5.6s
# [CV] activation=relu, alpha=0.0001, hidden_layer_sizes=200, learning_rate_init=0.001
# [CV]  activation=relu, alpha=0.0001, hidden_layer_sizes=200, learning_rate_init=0.001, score=-3.003878086860533, total=   1.3s
# [CV] activation=relu, alpha=0.0001, hidden_layer_sizes=200, learning_rate_init=0.001
# [CV]  activation=relu, alpha=0.0001, hidden_layer_sizes=200, learning_rate_init=0.001, score=-3.1288839963947024, total=   5.5s
# [CV] activation=relu, alpha=0.0001, hidden_layer_sizes=200, learning_rate_init=0.001
# [CV]  activation=relu, alpha=0.0001, hidden_layer_sizes=200, learning_rate_init=0.001, score=-2.8403987255028262, total=   2.0s
# [CV] activation=relu, alpha=0.0001, hidden_layer_sizes=200, learning_rate_init=0.0001
# [CV]  activation=relu, alpha=0.0001, hidden_layer_sizes=200, learning_rate_init=0.0001, score=-3.0761820172109067, total=   4.6s
# [CV] activation=relu, alpha=0.0001, hidden_layer_sizes=200, learning_rate_init=0.0001
# [CV]  activation=relu, alpha=0.0001, hidden_layer_sizes=200, learning_rate_init=0.0001, score=-3.1605947116958184, total=   4.1s
# [CV] activation=relu, alpha=0.0001, hidden_layer_sizes=200, learning_rate_init=0.0001
# [CV]  activation=relu, alpha=0.0001, hidden_layer_sizes=200, learning_rate_init=0.0001, score=-3.0310444268490215, total=   3.9s
# [CV] activation=relu, alpha=0.0001, hidden_layer_sizes=200, learning_rate_init=0.0001
# [CV]  activation=relu, alpha=0.0001, hidden_layer_sizes=200, learning_rate_init=0.0001, score=-3.0197899699759607, total=  13.6s
# [CV] activation=relu, alpha=0.0001, hidden_layer_sizes=200, learning_rate_init=0.0001
# [CV]  activation=relu, alpha=0.0001, hidden_layer_sizes=200, learning_rate_init=0.0001, score=-2.79875617134179, total=   7.3s
# [Parallel(n_jobs=1)]: Done 360 out of 360 | elapsed: 23.7min finished
# GridSearchCV(cv=KFold(n_splits=5, random_state=42, shuffle=True),
#        error_score='raise',
#        estimator=MLPRegressor(activation='relu', alpha=0.0001, batch_size='auto', beta_1=0.9,
#        beta_2=0.999, early_stopping=False, epsilon=1e-08,
#        hidden_layer_sizes=(100,), learning_rate='constant',
#        learning_rate_init=0.001, max_iter=1000, momentum=0.9,
#        nesterovs_momentum=True, power_t=0.5, random_state=42, shuffle=True,
#        solver='adam', tol=0.0001, validation_fraction=0.1, verbose=False,
#        warm_start=False),
#        fit_params=None, iid=True, n_jobs=1,
#        param_grid={'hidden_layer_sizes': [50, 100, 150, 200], 'activation': ['logistic', 'relu'], 'learning_rate_init': [0.01, 0.001, 0.0001], 'alpha': [0.01, 0.001, 0.0001]},
#        pre_dispatch='2*n_jobs', refit=True, return_train_score='warn',
#        scoring='neg_mean_absolute_error', verbose=10)

# %%
mlp_3_GS.best_params_
# Out:
# {'activation': 'relu',
#  'alpha': 0.01,
#  'hidden_layer_sizes': 200,
#  'learning_rate_init': 0.0001}

# %%
mlp_3_mod = MLPRegressor(activation='relu', alpha=0.01, batch_size='auto', beta_1=0.9,
       beta_2=0.999, early_stopping=False, epsilon=1e-08,
       hidden_layer_sizes=(200), learning_rate='constant',
       learning_rate_init=0.0001, max_iter=1000, momentum=0.9,
       nesterovs_momentum=True, power_t=0.5, random_state=42,
       shuffle=True, solver='adam', tol=0.0001, validation_fraction=0.1,
       verbose=False, warm_start=False)

# %%
cross_val(X_3, y_3, mlp_3_mod)
# Out:
# MAE: 3.0168 (0.1187)
# MSE: 14.8222 (0.8945)
# -----------------------------------------

# %%
mlp_3_mod.fit(X_3, y_3)
# Out:
# MLPRegressor(activation='relu', alpha=0.01, batch_size='auto', beta_1=0.9,
#        beta_2=0.999, early_stopping=False, epsilon=1e-08,
#        hidden_layer_sizes=200, learning_rate='constant',
#        learning_rate_init=0.0001, max_iter=1000, momentum=0.9,
#        nesterovs_momentum=True, power_t=0.5, random_state=42, shuffle=True,
#        solver='adam', tol=0.0001, validation_fraction=0.1, verbose=False,
#        warm_start=False)

# %%
show_preds(mlp_3_mod, X_3, y_3, df_3_all)

# %% [markdown]
# ## Position 4

# %%
# Create an estimator object with the estimator and parameter candidates.
kfold = KFold(n_splits=5, random_state=seed, shuffle = True)
mlp_4_GS = GridSearchCV(estimator=base_MLP, param_grid=param_grid, verbose=10,
                        scoring='neg_mean_absolute_error', cv=kfold)

# %%
mlp_4_GS.fit(X_4, y_4)
# Out:
# Fitting 5 folds for each of 72 candidates, totalling 360 fits
# [CV] activation=logistic, alpha=0.01, hidden_layer_sizes=50, learning_rate_init=0.01
# [CV]  activation=logistic, alpha=0.01, hidden_layer_sizes=50, learning_rate_init=0.01, score=-2.8094406142085737, total=   0.7s
# [CV] activation=logistic, alpha=0.01, hidden_layer_sizes=50, learning_rate_init=0.01
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.7s remaining:    0.0s
# [CV]  activation=logistic, alpha=0.01, hidden_layer_sizes=50, learning_rate_init=0.01, score=-2.765320761734021, total=   1.0s
# [CV] activation=logistic, alpha=0.01, hidden_layer_sizes=50, learning_rate_init=0.01
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    1.8s remaining:    0.0s
# [CV]  activation=logistic, alpha=0.01, hidden_layer_sizes=50, learning_rate_init=0.01, score=-2.83575548818378, total=   0.8s
# [CV] activation=logistic, alpha=0.01, hidden_layer_sizes=50, learning_rate_init=0.01
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    2.7s remaining:    0.0s
# [CV]  activation=logistic, alpha=0.01, hidden_layer_sizes=50, learning_rate_init=0.01, score=-2.7549272733410244, total=   0.8s
# [CV] activation=logistic, alpha=0.01, hidden_layer_sizes=50, learning_rate_init=0.01
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    3.7s remaining:    0.0s
# [CV]  activation=logistic, alpha=0.01, hidden_layer_sizes=50, learning_rate_init=0.01, score=-2.7437271523258717, total=   0.6s
# [CV] activation=logistic, alpha=0.01, hidden_layer_sizes=50, learning_rate_init=0.001
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    4.4s remaining:    0.0s
# [CV]  activation=logistic, alpha=0.01, hidden_layer_sizes=50, learning_rate_init=0.001, score=-2.755170421827558, total=   1.3s
# [CV] activation=logistic, alpha=0.01, hidden_layer_sizes=50, learning_rate_init=0.001
# [Parallel(n_jobs=1)]: Done   6 out of   6 | elapsed:    5.8s remaining:    0.0s
# [CV]  activation=logistic, alpha=0.01, hidden_layer_sizes=50, learning_rate_init=0.001, score=-2.8047068342897785, total=   2.8s
# [CV] activation=logistic, alpha=0.01, hidden_layer_sizes=50, learning_rate_init=0.001
# [Parallel(n_jobs=1)]: Done   7 out of   7 | elapsed:    8.7s remaining:    0.0s
# [CV]  activation=logistic, alpha=0.01, hidden_layer_sizes=50, learning_rate_init=0.001, score=-2.747836328288468, total=   1.7s
# [CV] activation=logistic, alpha=0.01, hidden_layer_sizes=50, learning_rate_init=0.001
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed:   10.5s remaining:    0.0s
# [CV]  activation=logistic, alpha=0.01, hidden_layer_sizes=50, learning_rate_init=0.001, score=-2.796087077634527, total=   2.5s
# [CV] activation=logistic, alpha=0.01, hidden_layer_sizes=50, learning_rate_init=0.001
# [Parallel(n_jobs=1)]: Done   9 out of   9 | elapsed:   13.1s remaining:    0.0s
# [CV]  activation=logistic, alpha=0.01, hidden_layer_sizes=50, learning_rate_init=0.001, score=-2.7846903229829123, total=   4.3s
# [CV] activation=logistic, alpha=0.01, hidden_layer_sizes=50, learning_rate_init=0.0001
# [CV]  activation=logistic, alpha=0.01, hidden_layer_sizes=50, learning_rate_init=0.0001, score=-2.7876003546459525, total=   7.9s
# [CV] activation=logistic, alpha=0.01, hidden_layer_sizes=50, learning_rate_init=0.0001
# [CV]  activation=logistic, alpha=0.01, hidden_layer_sizes=50, learning_rate_init=0.0001, score=-2.794796330678049, total=   7.9s
# [CV] activation=logistic, alpha=0.01, hidden_layer_sizes=50, learning_rate_init=0.0001
# [CV]  activation=logistic, alpha=0.01, hidden_layer_sizes=50, learning_rate_init=0.0001, score=-2.786375825623341, total=   8.1s
# [CV] activation=logistic, alpha=0.01, hidden_layer_sizes=50, learning_rate_init=0.0001
# [CV]  activation=logistic, alpha=0.01, hidden_layer_sizes=50, learning_rate_init=0.0001, score=-2.7952289101895764, total=   8.1s
# [CV] activation=logistic, alpha=0.01, hidden_layer_sizes=50, learning_rate_init=0.0001
# [CV]  activation=logistic, alpha=0.01, hidden_layer_sizes=50, learning_rate_init=0.0001, score=-2.7229641766268275, total=   5.9s
# [CV] activation=logistic, alpha=0.01, hidden_layer_sizes=100, learning_rate_init=0.01
# [CV]  activation=logistic, alpha=0.01, hidden_layer_sizes=100, learning_rate_init=0.01, score=-2.795439546365138, total=   1.1s
# [CV] activation=logistic, alpha=0.01, hidden_layer_sizes=100, learning_rate_init=0.01
# [CV]  activation=logistic, alpha=0.01, hidden_layer_sizes=100, learning_rate_init=0.01, score=-2.745989338576146, total=   1.0s
# [CV] activation=logistic, alpha=0.01, hidden_layer_sizes=100, learning_rate_init=0.01
# [CV]  activation=logistic, alpha=0.01, hidden_layer_sizes=100, learning_rate_init=0.01, score=-2.7308508733701715, total=   1.3s
# [CV] activation=logistic, alpha=0.01, hidden_layer_sizes=100, learning_rate_init=0.01
# [CV]  activation=logistic, alpha=0.01, hidden_layer_sizes=100, learning_rate_init=0.01, score=-2.7835346959774196, total=   0.9s
# [CV] activation=logistic, alpha=0.01, hidden_layer_sizes=100, learning_rate_init=0.01
# [CV]  activation=logistic, alpha=0.01, hidden_layer_sizes=100, learning_rate_init=0.01, score=-2.7408900169010244, total=   1.6s
# [CV] activation=logistic, alpha=0.01, hidden_layer_sizes=100, learning_rate_init=0.001
# [CV]  activation=logistic, alpha=0.01, hidden_layer_sizes=100, learning_rate_init=0.001, score=-2.7545732999979795, total=   3.2s
# [CV] activation=logistic, alpha=0.01, hidden_layer_sizes=100, learning_rate_init=0.001
# [CV]  activation=logistic, alpha=0.01, hidden_layer_sizes=100, learning_rate_init=0.001, score=-2.751877819587074, total=   2.7s
# [CV] activation=logistic, alpha=0.01, hidden_layer_sizes=100, learning_rate_init=0.001
# [CV]  activation=logistic, alpha=0.01, hidden_layer_sizes=100, learning_rate_init=0.001, score=-2.77358522315689, total=   1.8s
# [CV] activation=logistic, alpha=0.01, hidden_layer_sizes=100, learning_rate_init=0.001
# [CV]  activation=logistic, alpha=0.01, hidden_layer_sizes=100, learning_rate_init=0.001, score=-2.764006835179052, total=   3.6s
# [CV] activation=logistic, alpha=0.01, hidden_layer_sizes=100, learning_rate_init=0.001
# [CV]  activation=logistic, alpha=0.01, hidden_layer_sizes=100, learning_rate_init=0.001, score=-2.7123084194813254, total=   2.0s
# [CV] activation=logistic, alpha=0.01, hidden_layer_sizes=100, learning_rate_init=0.0001
# [CV]  activation=logistic, alpha=0.01, hidden_layer_sizes=100, learning_rate_init=0.0001, score=-2.783587289773475, total=   5.7s
# [CV] activation=logistic, alpha=0.01, hidden_layer_sizes=100, learning_rate_init=0.0001
# [CV]  activation=logistic, alpha=0.01, hidden_layer_sizes=100, learning_rate_init=0.0001, score=-2.7997452070341047, total=   8.8s
# [CV] activation=logistic, alpha=0.01, hidden_layer_sizes=100, learning_rate_init=0.0001
# [CV]  activation=logistic, alpha=0.01, hidden_layer_sizes=100, learning_rate_init=0.0001, score=-2.7852738008924574, total=   6.8s
# [CV] activation=logistic, alpha=0.01, hidden_layer_sizes=100, learning_rate_init=0.0001
# [CV]  activation=logistic, alpha=0.01, hidden_layer_sizes=100, learning_rate_init=0.0001, score=-2.7536246585432007, total=   7.9s
# [CV] activation=logistic, alpha=0.01, hidden_layer_sizes=100, learning_rate_init=0.0001
# [CV]  activation=logistic, alpha=0.01, hidden_layer_sizes=100, learning_rate_init=0.0001, score=-2.723299781168627, total=   8.3s
# [CV] activation=logistic, alpha=0.01, hidden_layer_sizes=150, learning_rate_init=0.01
# [CV]  activation=logistic, alpha=0.01, hidden_layer_sizes=150, learning_rate_init=0.01, score=-2.806770078797772, total=   1.4s
# [CV] activation=logistic, alpha=0.01, hidden_layer_sizes=150, learning_rate_init=0.01
# [CV]  activation=logistic, alpha=0.01, hidden_layer_sizes=150, learning_rate_init=0.01, score=-2.812381234967364, total=   1.0s
# [CV] activation=logistic, alpha=0.01, hidden_layer_sizes=150, learning_rate_init=0.01
# [CV]  activation=logistic, alpha=0.01, hidden_layer_sizes=150, learning_rate_init=0.01, score=-2.8859724749796296, total=   1.4s
# [CV] activation=logistic, alpha=0.01, hidden_layer_sizes=150, learning_rate_init=0.01
# [CV]  activation=logistic, alpha=0.01, hidden_layer_sizes=150, learning_rate_init=0.01, score=-2.923174915893777, total=   1.7s
# [CV] activation=logistic, alpha=0.01, hidden_layer_sizes=150, learning_rate_init=0.01
# [CV]  activation=logistic, alpha=0.01, hidden_layer_sizes=150, learning_rate_init=0.01, score=-2.6703969641031353, total=   1.3s
# [CV] activation=logistic, alpha=0.01, hidden_layer_sizes=150, learning_rate_init=0.001
# [CV]  activation=logistic, alpha=0.01, hidden_layer_sizes=150, learning_rate_init=0.001, score=-2
6s
# [CV] activation=relu, alpha=0.0001, hidden_layer_sizes=150, learning_rate_init=0.001
# [CV]  activation=relu, alpha=0.0001, hidden_layer_sizes=150, learning_rate_init=0.001, score=-2.9072954656526466, total=   1.1s
# [CV] activation=relu, alpha=0.0001, hidden_layer_sizes=150, learning_rate_init=0.001
# [CV]  activation=relu, alpha=0.0001, hidden_layer_sizes=150, learning_rate_init=0.001, score=-2.756476960254497, total=   4.6s
# [CV] activation=relu, alpha=0.0001, hidden_layer_sizes=150, learning_rate_init=0.0001
# [CV]  activation=relu, alpha=0.0001, hidden_layer_sizes=150, learning_rate_init=0.0001, score=-2.8111602585271607, total=  11.0s
# [CV] activation=relu, alpha=0.0001, hidden_layer_sizes=150, learning_rate_init=0.0001
# [CV]  activation=relu, alpha=0.0001, hidden_layer_sizes=150, learning_rate_init=0.0001, score=-2.8081452166352117, total=   5.7s
# [CV] activation=relu, alpha=0.0001, hidden_layer_sizes=150, learning_rate_init=0.0001
# [CV]  activation=relu, alpha=0.0001, hidden_layer_sizes=150, learning_rate_init=0.0001, score=-2.795493778671751, total=   6.8s
# [CV] activation=relu, alpha=0.0001, hidden_layer_sizes=150, learning_rate_init=0.0001
# [CV]  activation=relu, alpha=0.0001, hidden_layer_sizes=150, learning_rate_init=0.0001, score=-2.789123131019508, total=   9.3s
# [CV] activation=relu, alpha=0.0001, hidden_layer_sizes=150, learning_rate_init=0.0001
# [CV]  activation=relu, alpha=0.0001, hidden_layer_sizes=150, learning_rate_init=0.0001, score=-2.7365217208446917, total=   4.9s
# [CV] activation=relu, alpha=0.0001, hidden_layer_sizes=200, learning_rate_init=0.01
# [CV]  activation=relu, alpha=0.0001, hidden_layer_sizes=200, learning_rate_init=0.01, score=-2.7116712897643698, total=   1.1s
# [CV] activation=relu, alpha=0.0001, hidden_layer_sizes=200, learning_rate_init=0.01
# [CV]  activation=relu, alpha=0.0001, hidden_layer_sizes=200, learning_rate_init=0.01, score=-2.846487312775312, total=   0.9s
# [CV] activation=relu, alpha=0.0001, hidden_layer_sizes=200, learning_rate_init=0.01
# [CV]  activation=relu, alpha=0.0001, hidden_layer_sizes=200, learning_rate_init=0.01, score=-2.7961493631792957, total=   1.3s
# [CV] activation=relu, alpha=0.0001, hidden_layer_sizes=200, learning_rate_init=0.01
# [CV]  activation=relu, alpha=0.0001, hidden_layer_sizes=200, learning_rate_init=0.01, score=-2.7240873122772675, total=   2.3s
# [CV] activation=relu, alpha=0.0001, hidden_layer_sizes=200, learning_rate_init=0.01
# [CV]  activation=relu, alpha=0.0001, hidden_layer_sizes=200, learning_rate_init=0.01, score=-2.6962472051446915, total=   1.8s
# [CV] activation=relu, alpha=0.0001, hidden_layer_sizes=200, learning_rate_init=0.001
# [CV]  activation=relu, alpha=0.0001, hidden_layer_sizes=200, learning_rate_init=0.001, score=-3.2522435843034128, total=  12.5s
# [CV] activation=relu, alpha=0.0001, hidden_layer_sizes=200, learning_rate_init=0.001
# [CV]  activation=relu, alpha=0.0001, hidden_layer_sizes=200, learning_rate_init=0.001, score=-3.0851835562698446, total=   9.5s
# [CV] activation=relu, alpha=0.0001, hidden_layer_sizes=200, learning_rate_init=0.001
# [CV]  activation=relu, alpha=0.0001, hidden_layer_sizes=200, learning_rate_init=0.001, score=-3.421081080584084, total=  12.0s
# [CV] activation=relu, alpha=0.0001, hidden_layer_sizes=200, learning_rate_init=0.001
# [CV]  activation=relu, alpha=0.0001, hidden_layer_sizes=200, learning_rate_init=0.001, score=-3.0733499252360232, total=   9.6s
# [CV] activation=relu, alpha=0.0001, hidden_layer_sizes=200, learning_rate_init=0.001
# [CV]  activation=relu, alpha=0.0001, hidden_layer_sizes=200, learning_rate_init=0.001, score=-2.733287123131962, total=   1.9s
# [CV] activation=relu, alpha=0.0001, hidden_layer_sizes=200, learning_rate_init=0.0001
# [CV]  activation=relu, alpha=0.0001, hidden_layer_sizes=200, learning_rate_init=0.0001, score=-2.8075757048090084, total=  14.3s
# [CV] activation=relu, alpha=0.0001, hidden_layer_sizes=200, learning_rate_init=0.0001
# [CV]  activation=relu, alpha=0.0001, hidden_layer_sizes=200, learning_rate_init=0.0001, score=-2.8669895079263648, total=  26.6s
# [CV] activation=relu, alpha=0.0001, hidden_layer_sizes=200, learning_rate_init=0.0001
# [CV]  activation=relu, alpha=0.0001, hidden_layer_sizes=200, learning_rate_init=0.0001, score=-2.930635019926532, total=  19.9s
# [CV] activation=relu, alpha=0.0001, hidden_layer_sizes=200, learning_rate_init=0.0001
# [CV]  activation=relu, alpha=0.0001, hidden_layer_sizes=200, learning_rate_init=0.0001, score=-2.841522215582676, total=   7.7s
# [CV] activation=relu, alpha=0.0001, hidden_layer_sizes=200, learning_rate_init=0.0001
# [CV]  activation=relu, alpha=0.0001, hidden_layer_sizes=200, learning_rate_init=0.0001, score=-2.733677371952746, total=   8.0s
# [Parallel(n_jobs=1)]: Done 360 out of 360 | elapsed: 28.3min finished
# GridSearchCV(cv=KFold(n_splits=5, random_state=42, shuffle=True),
#        error_score='raise',
#        estimator=MLPRegressor(activation='relu', alpha=0.0001, batch_size='auto', beta_1=0.9,
#        beta_2=0.999, early_stopping=False, epsilon=1e-08,
#        hidden_layer_sizes=(100,), learning_rate='constant',
#        learning_rate_init=0.001, max_iter=1000, momentum=0.9,
#        nesterovs_momentum=True, power_t=0.5, random_state=42, shuffle=True,
#        solver='adam', tol=0.0001, validation_fraction=0.1, verbose=False,
#        warm_start=False),
#        fit_params=None, iid=True, n_jobs=1,
#        param_grid={'hidden_layer_sizes': [50, 100, 150, 200], 'activation': ['logistic', 'relu'], 'learning_rate_init': [0.01, 0.001, 0.0001], 'alpha': [0.01, 0.001, 0.0001]},
#        pre_dispatch='2*n_jobs', refit=True, return_train_score='warn',
#        scoring='neg_mean_absolute_error', verbose=10)

# %%
mlp_4_GS.best_params_
# Out:
# {'activation': 'relu',
#  'alpha': 0.01,
#  'hidden_layer_sizes': 150,
#  'learning_rate_init': 0.01}

# %%
mlp_4_mod = MLPRegressor(activation='relu', alpha=0.01, batch_size='auto', beta_1=0.9,
       beta_2=0.999, early_stopping=False, epsilon=1e-08,
       hidden_layer_sizes=(150,), learning_rate='constant',
       learning_rate_init=0.01, max_iter=1000, momentum=0.9,
       nesterovs_momentum=True, power_t=0.5, random_state=42,
       shuffle=True, solver='adam', tol=0.0001, validation_fraction=0.1,
       verbose=False, warm_start=False)

# %%
cross_val(X_4, y_4, mlp_4_mod)
# Out:
# MAE: 2.7399 (0.0480)
# MSE: 14.0416 (0.1279)
# -----------------------------------------

# %%
mlp_4_mod.fit(X_4, y_4)
# Out:
# MLPRegressor(activation='relu', alpha=0.01, batch_size='auto', beta_1=0.9,
#        beta_2=0.999, early_stopping=False, epsilon=1e-08,
#        hidden_layer_sizes=(150,), learning_rate='constant',
#        learning_rate_init=0.01, max_iter=1000, momentum=0.9,
#        nesterovs_momentum=True, power_t=0.5, random_state=42, shuffle=True,
#        solver='adam', tol=0.0001, validation_fraction=0.1, verbose=False,
#        warm_start=False)

# %%
show_preds(mlp_4_mod, X_4, y_4, df_4_all)

# %% [markdown]
# ## Position 5

# %%
# Create an estimator object with the estimator and parameter candidates.
kfold = KFold(n_splits=5, random_state=seed, shuffle = True)
mlp_5_GS = GridSearchCV(estimator=base_MLP, param_grid=param_grid, verbose=10,
                        scoring='neg_mean_absolute_error', cv=kfold)

# %%
mlp_5_GS.fit(X_5, y_5)
# Out:
# Fitting 5 folds for each of 72 candidates, totalling 360 fits
# [CV] activation=logistic, alpha=0.01, hidden_layer_sizes=50, learning_rate_init=0.01
# [CV]  activation=logistic, alpha=0.01, hidden_layer_sizes=50, learning_rate_init=0.01, score=-3.464770932106437, total=   0.4s
# [CV] activation=logistic, alpha=0.01, hidden_layer_sizes=50, learning_rate_init=0.01
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.4s remaining:    0.0s
# [CV]  activation=logistic, alpha=0.01, hidden_layer_sizes=50, learning_rate_init=0.01, score=-3.1711315251165, total=   0.7s
# [CV] activation=logistic, alpha=0.01, hidden_layer_sizes=50, learning_rate_init=0.01
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    1.3s remaining:    0.0s
# [CV]  activation=logistic, alpha=0.01, hidden_layer_sizes=50, learning_rate_init=0.01, score=-3.2863101935139323, total=   0.4s
# [CV] activation=logistic, alpha=0.01, hidden_layer_sizes=50, learning_rate_init=0.01
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    1.8s remaining:    0.0s
# [CV]  activation=logistic, alpha=0.01, hidden_layer_sizes=50, learning_rate_init=0.01, score=-3.3411898831932456, total=   0.6s
# [CV] activation=logistic, alpha=0.01, hidden_layer_sizes=50, learning_rate_init=0.01
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    2.4s remaining:    0.0s
# [CV]  activation=logistic, alpha=0.01, hidden_layer_sizes=50, learning_rate_init=0.01, score=-3.4460659304769465, total=   0.8s
# [CV] activation=logistic, alpha=0.01, hidden_layer_sizes=50, learning_rate_init=0.001
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    3.4s remaining:    0.0s
# [CV]  activation=logistic, alpha=0.01, hidden_layer_sizes=50, learning_rate_init=0.001, score=-3.3720203421186046, total=   1.3s
# [CV] activation=logistic, alpha=0.01, hidden_layer_sizes=50, learning_rate_init=0.001
# [Parallel(n_jobs=1)]: Done   6 out of   6 | elapsed:    4.8s remaining:    0.0s
# [CV]  activation=logistic, alpha=0.01, hidden_layer_sizes=50, learning_rate_init=0.001, score=-3.144348496930405, total=   2.3s
# [CV] activation=logistic, alpha=0.01, hidden_layer_sizes=50, learning_rate_init=0.001
# [Parallel(n_jobs=1)]: Done   7 out of   7 | elapsed:    7.3s remaining:    0.0s
# [CV]  activation=logistic, alpha=0.01, hidden_layer_sizes=50, learning_rate_init=0.001, score=-3.2575524347127387, total=   1.6s
# [CV] activation=logistic, alpha=0.01, hidden_layer_sizes=50, learning_rate_init=0.001
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed:    8.9s remaining:    0.0s
# [CV]  activation=logistic, alpha=0.01, hidden_layer_sizes=50, learning_rate_init=0.001, score=-3.1967798469292505, total=   2.4s
# [CV] activation=logistic, alpha=0.01, hidden_layer_sizes=50, learning_rate_init=0.001
# [Parallel(n_jobs=1)]: Done   9 out of   9 | elapsed:   11.5s remaining:    0.0s
# [CV]  activation=logistic, alpha=0.01, hidden_layer_sizes=50, learning_rate_init=0.001, score=-3.3203740923108938, total=   2.3s
# [CV] activation=logistic, alpha=0.01, hidden_layer_sizes=50, learning_rate_init=0.0001
# [CV]  activation=logistic, alpha=0.01, hidden_layer_sizes=50, learning_rate_init=0.0001, score=-3.4129783032975016, total=   7.6s
# [CV] activation=logistic, alpha=0.01, hidden_layer_sizes=50, learning_rate_init=0.0001
# [CV]  activation=logistic, alpha=0.01, hidden_layer_sizes=50, learning_rate_init=0.0001, score=-3.143894264040194, total=   4.4s
# [CV] activation=logistic, alpha=0.01, hidden_layer_sizes=50, learning_rate_init=0.0001
# [CV]  activation=logistic, alpha=0.01, hidden_layer_sizes=50, learning_rate_init=0.0001, score=-3.260283771551657, total=   7.9s
# [CV] activation=logistic, alpha=0.01, hidden_layer_sizes=50, learning_rate_init=0.0001
# [CV]  activation=logistic, alpha=0.01, hidden_layer_sizes=50, learning_rate_init=0.0001, score=-3.2721595463703745, total=   6.0s
# [CV] activation=logistic, alpha=0.01, hidden_layer_sizes=50, learning_rate_init=0.0001
# [CV]  activation=logistic, alpha=0.01, hidden_layer_sizes=50, learning_rate_init=0.0001, score=-3.3702876104026624, total=   4.2s
# [CV] activation=logistic, alpha=0.01, hidden_layer_sizes=100, learning_rate_init=0.01
# [CV]  activation=logistic, alpha=0.01, hidden_layer_sizes=100, learning_rate_init=0.01, score=-3.441085812996069, total=   0.8s
# [CV] activation=logistic, alpha=0.01, hidden_layer_sizes=100, learning_rate_init=0.01
# [CV]  activation=logistic, alpha=0.01, hidden_layer_sizes=100, learning_rate_init=0.01, score=-3.097635936755225, total=   1.0s
# [CV] activation=logistic, alpha=0.01, hidden_layer_sizes=100, learning_rate_init=0.01
# [CV]  activation=logistic, alpha=0.01, hidden_layer_sizes=100, learning_rate_init=0.01, score=-3.301194717971335, total=   1.0s
# [CV] activation=logistic, alpha=0.01, hidden_layer_sizes=100, learning_rate_init=0.01
# [CV]  activation=logistic, alpha=0.01, hidden_layer_sizes=100, learning_rate_init=0.01, score=-3.367513953816966, total=   0.5s
# [CV] activation=logistic, alpha=0.01, hidden_layer_sizes=100, learning_rate_init=0.01
# [CV]  activation=logistic, alpha=0.01, hidden_layer_sizes=100, learning_rate_init=0.01, score=-3.3999371133855525, total=   0.9s
# [CV] activation=logistic, alpha=0.01, hidden_layer_sizes=100, learning_rate_init=0.001
# [CV]  activation=logistic, alpha=0.01, hidden_layer_sizes=100, learning_rate_init=0.001, score=-3.4633611053916216, total=   2.3s
# [CV] activation=logistic, alpha=0.01, hidden_layer_sizes=100, learning_rate_init=0.001
# [CV]  activation=logistic, alpha=0.01, hidden_layer_sizes=100, learning_rate_init=0.001, score=-3.2347262820479945, total=   2.8s
# [CV] activation=logistic, alpha=0.01, hidden_layer_sizes=100, learning_rate_init=0.001
# [CV]  activation=logistic, alpha=0.01, hidden_layer_sizes=100, learning_rate_init=0.001, score=-3.3016653161745984, total=   2.3s
# [CV] activation=logistic, alpha=0.01, hidden_layer_sizes=100, learning_rate_init=0.001
# [CV]  activation=logistic, alpha=0.01, hidden_layer_sizes=100, learning_rate_init=0.001, score=-3.3415940394849564, total=   0.9s
# [CV] activation=logistic, alpha=0.01, hidden_layer_sizes=100, learning_rate_init=0.001
# [CV]  activation=logistic, alpha=0.01, hidden_layer_sizes=100, learning_rate_init=0.001, score=-3.3955469211572074, total=   2.3s
# [CV] activation=logistic, alpha=0.01, hidden_layer_sizes=100, learning_rate_init=0.0001
# [CV]  activation=logistic, alpha=0.01, hidden_layer_sizes=100, learning_rate_init=0.0001, score=-3.420680024931762, total=   5.8s
# [CV] activation=logistic, alpha=0.01, hidden_layer_sizes=100, learning_rate_init=0.0001
# [CV]  activation=logistic, alpha=0.01, hidden_layer_sizes=100, learning_rate_init=0.0001, score=-3.1746280094632713, total=   7.4s
# [CV] activation=logistic, alpha=0.01, hidden_layer_sizes=100, learning_rate_init=0.0001
# [CV]  activation=logistic, alpha=0.01, hidden_layer_sizes=100, learning_rate_init=0.0001, score=-3.263105011398433, total=   8.1s
# [CV] activation=logistic, alpha=0.01, hidden_layer_sizes=100, learning_rate_init=0.0001
# [CV]  activation=logistic, alpha=0.01, hidden_layer_sizes=100, learning_rate_init=0.0001, score=-3.2788030819431357, total=   5.3s
# [CV] activation=logistic, alpha=0.01, hidden_layer_sizes=100, learning_rate_init=0.0001
# [CV]  activation=logistic, alpha=0.01, hidden_layer_sizes=100, learning_rate_init=0.0001, score=-3.3425562844378325, total=   7.9s
# [CV] activation=logistic, alpha=0.01, hidden_layer_sizes=150, learning_rate_init=0.01
# [CV]  activation=logistic, alpha=0.01, hidden_layer_sizes=150, learning_rate_init=0.01, score=-3.29603704075273, total=   1.3s
# [CV] activation=logistic, alpha=0.01, hidden_layer_sizes=150, learning_rate_init=0.01
# [CV]  activation=logistic, alpha=0.01, hidden_layer_sizes=150, learning_rate_init=0.01, score=-3.2560823922210322, total=   1.5s
# [CV] activation=logistic, alpha=0.01, hidden_layer_sizes=150, learning_rate_init=0.01
# [CV]  activation=logistic, alpha=0.01, hidden_layer_sizes=150, learning_rate_init=0.01, score=-3.192112655704431, total=   2.3s
# [CV] activation=logistic, alpha=0.01, hidden_layer_sizes=150, learning_rate_init=0.01
# [CV]  activation=logistic, alpha=0.01, hidden_layer_sizes=150, learning_rate_init=0.01, score=-3.219700843161305, total=   1.0s
# [CV] activation=logistic, alpha=0.01, hidden_layer_sizes=150, learning_rate_init=0.01
# [CV]  activation=logistic, alpha=0.01, hidden_layer_sizes=150, learning_rate_init=0.01, score=-3.2609314297177887, total=   1.1s
# [CV] activation=logistic, alpha=0.01, hidden_layer_sizes=150, learning_rate_init=0.001
# [CV]  activation=logistic, alpha=0.01, hidden_layer_sizes=150, learning_rate_init=0.001, score=-3.377131347050482, total=   1.5s
# [CV] activation=logistic, alpha=0.01, hidden_layer_sizes=150, learning_rate_init=0.001
# [CV]  activation=logistic, alpha=0.01, hidden_layer_sizes=150, learning_rate_init=0.001, score=-3.2082604151879472, total=   2.3s
# [CV] activation=logistic, alpha=0.01, hidden_layer_sizes=150, learning_rate_init=0.001
# [CV]  activation=logistic, alpha=0.01, hidden_layer_sizes=150, learning_rate_init=0.001, score=-3
0s
# [CV] activation=relu, alpha=0.0001, hidden_layer_sizes=200, learning_rate_init=0.01
# [CV]  activation=relu, alpha=0.0001, hidden_layer_sizes=200, learning_rate_init=0.01, score=-3.4555174222328313, total=   1.5s
# [CV] activation=relu, alpha=0.0001, hidden_layer_sizes=200, learning_rate_init=0.001
# [CV]  activation=relu, alpha=0.0001, hidden_layer_sizes=200, learning_rate_init=0.001, score=-3.3637012000692708, total=   2.2s
# [CV] activation=relu, alpha=0.0001, hidden_layer_sizes=200, learning_rate_init=0.001
# [CV]  activation=relu, alpha=0.0001, hidden_layer_sizes=200, learning_rate_init=0.001, score=-3.3370596995674005, total=   1.3s
# [CV] activation=relu, alpha=0.0001, hidden_layer_sizes=200, learning_rate_init=0.001
# [CV]  activation=relu, alpha=0.0001, hidden_layer_sizes=200, learning_rate_init=0.001, score=-3.1229680853504616, total=   1.0s
# [CV] activation=relu, alpha=0.0001, hidden_layer_sizes=200, learning_rate_init=0.001
# [CV]  activation=relu, alpha=0.0001, hidden_layer_sizes=200, learning_rate_init=0.001, score=-3.1513525048250544, total=   2.4s
# [CV] activation=relu, alpha=0.0001, hidden_layer_sizes=200, learning_rate_init=0.001
# [CV]  activation=relu, alpha=0.0001, hidden_layer_sizes=200, learning_rate_init=0.001, score=-3.46566593375201, total=   1.0s
# [CV] activation=relu, alpha=0.0001, hidden_layer_sizes=200, learning_rate_init=0.0001
# [CV]  activation=relu, alpha=0.0001, hidden_layer_sizes=200, learning_rate_init=0.0001, score=-3.4017740713377576, total=   4.6s
# [CV] activation=relu, alpha=0.0001, hidden_layer_sizes=200, learning_rate_init=0.0001
# [CV]  activation=relu, alpha=0.0001, hidden_layer_sizes=200, learning_rate_init=0.0001, score=-3.185957559484196, total=   4.8s
# [CV] activation=relu, alpha=0.0001, hidden_layer_sizes=200, learning_rate_init=0.0001
# [CV]  activation=relu, alpha=0.0001, hidden_layer_sizes=200, learning_rate_init=0.0001, score=-3.2450849214500903, total=   2.4s
# [CV] activation=relu, alpha=0.0001, hidden_layer_sizes=200, learning_rate_init=0.0001
# [CV]  activation=relu, alpha=0.0001, hidden_layer_sizes=200, learning_rate_init=0.0001, score=-3.2789532360153966, total=   6.7s
# [CV] activation=relu, alpha=0.0001, hidden_layer_sizes=200, learning_rate_init=0.0001
# [CV]  activation=relu, alpha=0.0001, hidden_layer_sizes=200, learning_rate_init=0.0001, score=-3.354595000394274, total=   2.3s
# [Parallel(n_jobs=1)]: Done 360 out of 360 | elapsed: 16.9min finished
# GridSearchCV(cv=KFold(n_splits=5, random_state=42, shuffle=True),
#        error_score='raise',
#        estimator=MLPRegressor(activation='relu', alpha=0.0001, batch_size='auto', beta_1=0.9,
#        beta_2=0.999, early_stopping=False, epsilon=1e-08,
#        hidden_layer_sizes=(100,), learning_rate='constant',
#        learning_rate_init=0.001, max_iter=1000, momentum=0.9,
#        nesterovs_momentum=True, power_t=0.5, random_state=42, shuffle=True,
#        solver='adam', tol=0.0001, validation_fraction=0.1, verbose=False,
#        warm_start=False),
#        fit_params=None, iid=True, n_jobs=1,
#        param_grid={'hidden_layer_sizes': [50, 100, 150, 200], 'activation': ['logistic', 'relu'], 'learning_rate_init': [0.01, 0.001, 0.0001], 'alpha': [0.01, 0.001, 0.0001]},
#        pre_dispatch='2*n_jobs', refit=True, return_train_score='warn',
#        scoring='neg_mean_absolute_error', verbose=10)

# %%
mlp_5_GS.best_params_
# Out:
# {'activation': 'relu',
#  'alpha': 0.001,
#  'hidden_layer_sizes': 200,
#  'learning_rate_init': 0.01}

# %%
mlp_5_mod = MLPRegressor(activation='relu', alpha=0.001, batch_size='auto', beta_1=0.9,
       beta_2=0.999, early_stopping=False, epsilon=1e-08,
       hidden_layer_sizes=(200,), learning_rate='constant',
       learning_rate_init=0.01, max_iter=1000, momentum=0.9,
       nesterovs_momentum=True, power_t=0.5, random_state=42,
       shuffle=True, solver='adam', tol=0.0001, validation_fraction=0.1,
       verbose=False, warm_start=False)

# %%
cross_val(X_5, y_5, mlp_5_mod)
# Out:
# MAE: 3.2272 (0.1655)
# MSE: 20.1524 (1.4867)
# -----------------------------------------

# %%
mlp_5_mod.fit(X_5, y_5)
# Out:
# MLPRegressor(activation='relu', alpha=0.001, batch_size='auto', beta_1=0.9,
#        beta_2=0.999, early_stopping=False, epsilon=1e-08,
#        hidden_layer_sizes=(200,), learning_rate='constant',
#        learning_rate_init=0.01, max_iter=1000, momentum=0.9,
#        nesterovs_momentum=True, power_t=0.5, random_state=42, shuffle=True,
#        solver='adam', tol=0.0001, validation_fraction=0.1, verbose=False,
#        warm_start=False)

# %%
show_preds(mlp_5_mod, X_5, y_5, df_5_all)

# %% [markdown]
# ## Position 6

# %%
# Create an estimator object with the estimator and parameter candidates.
kfold = KFold(n_splits=5, random_state=seed, shuffle = True)
mlp_6_GS = GridSearchCV(estimator=base_MLP, param_grid=param_grid, verbose=10,
                        scoring='neg_mean_absolute_error', cv=kfold)

# %%
mlp_6_GS.fit(X_6, y_6)
# Out:
# Fitting 5 folds for each of 72 candidates, totalling 360 fits
# [CV] activation=logistic, alpha=0.01, hidden_layer_sizes=50, learning_rate_init=0.01
# [CV]  activation=logistic, alpha=0.01, hidden_layer_sizes=50, learning_rate_init=0.01, score=-1.741951465877519, total=   0.0s
# [CV] activation=logistic, alpha=0.01, hidden_layer_sizes=50, learning_rate_init=0.01
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.2s remaining:    0.0s
# [CV]  activation=logistic, alpha=0.01, hidden_layer_sizes=50, learning_rate_init=0.01, score=-1.7559272525205798, total=   0.0s
# [CV] activation=logistic, alpha=0.01, hidden_layer_sizes=50, learning_rate_init=0.01
# [CV]  activation=logistic, alpha=0.01, hidden_layer_sizes=50, learning_rate_init=0.01, score=-1.723818412843986, total=   0.0s
# [CV] activation=logistic, alpha=0.01, hidden_layer_sizes=50, learning_rate_init=0.01
# [CV]  activation=logistic, alpha=0.01, hidden_layer_sizes=50, learning_rate_init=0.01, score=-1.6869884198190963, total=   0.0s
# [CV] activation=logistic, alpha=0.01, hidden_layer_sizes=50, learning_rate_init=0.01
# [CV]  activation=logistic, alpha=0.01, hidden_layer_sizes=50, learning_rate_init=0.01, score=-1.8208359727398755, total=   0.0s
# [CV] activation=logistic, alpha=0.01, hidden_layer_sizes=50, learning_rate_init=0.001
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.3s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    0.4s remaining:    0.0s
# [CV]  activation=logistic, alpha=0.01, hidden_layer_sizes=50, learning_rate_init=0.001, score=-1.646110687896829, total=   1.1s
# [CV] activation=logistic, alpha=0.01, hidden_layer_sizes=50, learning_rate_init=0.001
# [Parallel(n_jobs=1)]: Done   6 out of   6 | elapsed:    1.6s remaining:    0.0s
# [CV]  activation=logistic, alpha=0.01, hidden_layer_sizes=50, learning_rate_init=0.001, score=-1.644897499368245, total=   0.9s
# [CV] activation=logistic, alpha=0.01, hidden_layer_sizes=50, learning_rate_init=0.001
# [Parallel(n_jobs=1)]: Done   7 out of   7 | elapsed:    2.7s remaining:    0.0s
# [CV]  activation=logistic, alpha=0.01, hidden_layer_sizes=50, learning_rate_init=0.001, score=-1.6627155653120593, total=   0.5s
# [CV] activation=logistic, alpha=0.01, hidden_layer_sizes=50, learning_rate_init=0.001
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed:    3.3s remaining:    0.0s
# [CV]  activation=logistic, alpha=0.01, hidden_layer_sizes=50, learning_rate_init=0.001, score=-1.5940968214238773, total=   0.8s
# [CV] activation=logistic, alpha=0.01, hidden_layer_sizes=50, learning_rate_init=0.001
# [Parallel(n_jobs=1)]: Done   9 out of   9 | elapsed:    4.2s remaining:    0.0s
# [CV]  activation=logistic, alpha=0.01, hidden_layer_sizes=50, learning_rate_init=0.001, score=-1.7746121431525532, total=   0.7s
# [CV] activation=logistic, alpha=0.01, hidden_layer_sizes=50, learning_rate_init=0.0001
# [CV]  activation=logistic, alpha=0.01, hidden_layer_sizes=50, learning_rate_init=0.0001, score=-1.7091202646948018, total=   4.5s
# [CV] activation=logistic, alpha=0.01, hidden_layer_sizes=50, learning_rate_init=0.0001
# [CV]  activation=logistic, alpha=0.01, hidden_layer_sizes=50, learning_rate_init=0.0001, score=-1.6894666354493069, total=   3.3s
# [CV] activation=logistic, alpha=0.01, hidden_layer_sizes=50, learning_rate_init=0.0001
# [CV]  activation=logistic, alpha=0.01, hidden_layer_sizes=50, learning_rate_init=0.0001, score=-1.6686062208552674, total=   3.3s
# [CV] activation=logistic, alpha=0.01, hidden_layer_sizes=50, learning_rate_init=0.0001
# [CV]  activation=logistic, alpha=0.01, hidden_layer_sizes=50, learning_rate_init=0.0001, score=-1.6357147061089332, total=   3.4s
# [CV] activation=logistic, alpha=0.01, hidden_layer_sizes=50, learning_rate_init=0.0001
# [CV]  activation=logistic, alpha=0.01, hidden_layer_sizes=50, learning_rate_init=0.0001, score=-1.7930021067846753, total=   3.6s
# [CV] activation=logistic, alpha=0.01, hidden_layer_sizes=100, learning_rate_init=0.01
# [CV]  activation=logistic, alpha=0.01, hidden_layer_sizes=100, learning_rate_init=0.01, score=-1.6420492751383164, total=   0.4s
# [CV] activation=logistic, alpha=0.01, hidden_layer_sizes=100, learning_rate_init=0.01
# [CV]  activation=logistic, alpha=0.01, hidden_layer_sizes=100, learning_rate_init=0.01, score=-1.721008013064711, total=   0.0s
# [CV] activation=logistic, alpha=0.01, hidden_layer_sizes=100, learning_rate_init=0.01
# [CV]  activation=logistic, alpha=0.01, hidden_layer_sizes=100, learning_rate_init=0.01, score=-1.5946093003061308, total=   0.3s
# [CV] activation=logistic, alpha=0.01, hidden_layer_sizes=100, learning_rate_init=0.01
# [CV]  activation=logistic, alpha=0.01, hidden_layer_sizes=100, learning_rate_init=0.01, score=-1.5912739506743074, total=   0.3s
# [CV] activation=logistic, alpha=0.01, hidden_layer_sizes=100, learning_rate_init=0.01
# [CV]  activation=logistic, alpha=0.01, hidden_layer_sizes=100, learning_rate_init=0.01, score=-1.8065689479641733, total=   0.1s
# [CV] activation=logistic, alpha=0.01, hidden_layer_sizes=100, learning_rate_init=0.001
# [CV]  activation=logistic, alpha=0.01, hidden_layer_sizes=100, learning_rate_init=0.001, score=-1.6863891428985252, total=   0.6s
# [CV] activation=logistic, alpha=0.01, hidden_layer_sizes=100, learning_rate_init=0.001
# [CV]  activation=logistic, alpha=0.01, hidden_layer_sizes=100, learning_rate_init=0.001, score=-1.6882952636698694, total=   0.8s
# [CV] activation=logistic, alpha=0.01, hidden_layer_sizes=100, learning_rate_init=0.001
# [CV]  activation=logistic, alpha=0.01, hidden_layer_sizes=100, learning_rate_init=0.001, score=-1.596570125031051, total=   0.9s
# [CV] activation=logistic, alpha=0.01, hidden_layer_sizes=100, learning_rate_init=0.001
# [CV]  activation=logistic, alpha=0.01, hidden_layer_sizes=100, learning_rate_init=0.001, score=-1.6208546784662714, total=   0.8s
# [CV] activation=logistic, alpha=0.01, hidden_layer_sizes=100, learning_rate_init=0.001
# [CV]  activation=logistic, alpha=0.01, hidden_layer_sizes=100, learning_rate_init=0.001, score=-1.7780101580001682, total=   0.6s
# [CV] activation=logistic, alpha=0.01, hidden_layer_sizes=100, learning_rate_init=0.0001
# [CV]  activation=logistic, alpha=0.01, hidden_layer_sizes=100, learning_rate_init=0.0001, score=-1.7158681702454543, total=   2.8s
# [CV] activation=logistic, alpha=0.01, hidden_layer_sizes=100, learning_rate_init=0.0001
# [CV]  activation=logistic, alpha=0.01, hidden_layer_sizes=100, learning_rate_init=0.0001, score=-1.685453677745605, total=   2.5s
# [CV] activation=logistic, alpha=0.01, hidden_layer_sizes=100, learning_rate_init=0.0001
# [CV]  activation=logistic, alpha=0.01, hidden_layer_sizes=100, learning_rate_init=0.0001, score=-1.6811692503728812, total=   2.1s
# [CV] activation=logistic, alpha=0.01, hidden_layer_sizes=100, learning_rate_init=0.0001
# [CV]  activation=logistic, alpha=0.01, hidden_layer_sizes=100, learning_rate_init=0.0001, score=-1.601796940001176, total=   4.2s
# [CV] activation=logistic, alpha=0.01, hidden_layer_sizes=100, learning_rate_init=0.0001
# [CV]  activation=logistic, alpha=0.01, hidden_layer_sizes=100, learning_rate_init=0.0001, score=-1.796285893043913, total=   2.5s
# [CV] activation=logistic, alpha=0.01, hidden_layer_sizes=150, learning_rate_init=0.01
# [CV]  activation=logistic, alpha=0.01, hidden_layer_sizes=150, learning_rate_init=0.01, score=-1.7303883682973125, total=   0.3s
# [CV] activation=logistic, alpha=0.01, hidden_layer_sizes=150, learning_rate_init=0.01
# [CV]  activation=logistic, alpha=0.01, hidden_layer_sizes=150, learning_rate_init=0.01, score=-1.649615809826319, total=   0.4s
# [CV] activation=logistic, alpha=0.01, hidden_layer_sizes=150, learning_rate_init=0.01
# [CV]  activation=logistic, alpha=0.01, hidden_layer_sizes=150, learning_rate_init=0.01, score=-1.6023780374327368, total=   0.7s
# [CV] activation=logistic, alpha=0.01, hidden_layer_sizes=150, learning_rate_init=0.01
# [CV]  activation=logistic, alpha=0.01, hidden_layer_sizes=150, learning_rate_init=0.01, score=-1.673322887891954, total=   0.7s
# [CV] activation=logistic, alpha=0.01, hidden_layer_sizes=150, learning_rate_init=0.01
# [CV]  activation=logistic, alpha=0.01, hidden_layer_sizes=150, learning_rate_init=0.01, score=-1.7743819373188503, total=   0.4s
# [CV] activation=logistic, alpha=0.01, hidden_layer_sizes=150, learning_rate_init=0.001
# [CV]  activation=logistic, alpha=0.01, hidden_layer_sizes=150, learning_rate_init=0.001, score=-1.6554334273606675, total=   1.1s
# [CV] activation=logistic, alpha=0.01, hidden_layer_sizes=150, learning_rate_init=0.001
# [CV]  activation=logistic, alpha=0.01, hidden_layer_sizes=150, learning_rate_init=0.001, score=-1.7086052928207973, total=   1.2s
# [CV] activation=logistic, alpha=0.01, hidden_layer_sizes=150, learning_rate_init=0.001
# [CV]  activation=logistic, alpha=0.01, hidden_layer_sizes=150, learning_rate_init=0.001, score=-1.5865177360269886, total=   1.1s
# [CV] activation=logistic, alpha=0.01, hidden_layer_sizes=150, learning_rate_init=0.001
# [CV]  activation=logistic, alpha=0.01, hidden_layer_sizes=150, learning_rate_init=0.001, score=-1.5528850849981561, total=   1.1s
# [CV] activation=logistic, alpha=0.01, hidden_layer_sizes=150, learning_rate_init=0.001
# [CV]  activation=logistic, alpha=0.01, hidden_layer_sizes=150, learning_rate_init=0.001, score=-1.7715639700558508, total=   1.0s
# [CV] activation=logistic, alpha=0.01, hidden_layer_sizes=150, learning_rate_init=0.0001
# [CV]  activation=logistic, alpha=0.01, hidden_layer_sizes=150, learning_rate_init=0.0001, score=-1.710495115596311, total=   3.4s
# [CV] activation=logistic, alpha=0.01, hidden_layer_sizes=150, learning_rate_init=0.0001
# [CV]  activation=logistic, alpha=0.01, hidden_layer_sizes=150, learning_rate_init=0.0001, score=-1.692472517228243, total=   2.6s
# [CV] activation=logistic, alpha=0.01, hidden_layer_sizes=150, learning_rate_init=0.0001
# [CV]  activation=logistic, alpha=0.01, hidden_layer_sizes=150, learning_rate_init=0.0001, score=-1.6354965664542729, total=   5.6s
# [CV] activation=logistic, alpha=0.01, hidden_layer_sizes=150, learning_rate_init=0.0001
# [CV]  activation=logistic, alpha=0.01, hidden_layer_sizes=150, learning_rate_init=0.0001, score=-1.6338863427920343, total=   3.5s
# [CV] activation=logistic, alpha=0.01, hidden_layer_sizes=150, learning_rate_init=0.0001
# [CV]  activation=logistic, alpha=0.01, hidden_layer_sizes=150, learning_rate_init=0.0001, score=-1.785564957008523, total=   4.7s
# [CV] activation=logistic, alpha=0.01, hidden_layer_sizes=200, learning_rate_init=0.01
# [CV]  activation=logistic, alpha=0.01, hidden_layer_sizes=200, learning_rate_init=0.01, score=-1.8014504994264888, total=   0.3s
# [CV] activation=logistic, alpha=0.01, hidden_layer_sizes=200, learning_rate_init=0.01
# [CV]  activation=logistic, alpha=0.01, hidden_layer_sizes=200, learning_rate_init=0.01, score=-1.6912913334138415, total=   0.6s
# [CV] activation=logistic, alpha=0.01, hidden_layer_sizes=200, learning_rate_init=0.01
# [CV]  activation=logistic, alpha=0.01, hidden_layer_sizes=200, learning_rate_init=0.01, score=-1.711927933279715, total=   0.2s
# [CV] activation=logistic, alpha=0.01, hidden_layer_sizes=200, learning_rate_init=0.01
# [CV]  activation=logistic, alpha=0.01, hidden_layer_sizes=200, learning_rate_init=0.01, score=-1.7399031462090824, total=   0.2s
# [CV] activation=logistic, alpha=0.01, hidden_layer_sizes=200, learning_rate_init=0.01
# [CV]  activation=logistic, alpha=0.01, hidden_layer_sizes=200, learning_rate_init=0.01, score=-1.7656147867865688, total=   0.8s
# [CV] activation=logistic, alpha=0.01, hidden_layer_sizes=200, learning_rate_init=0.001
# [CV]  activation=logistic, alpha=0.01, hidden_layer_sizes=200, learning_rate_init=0.001, score=-1

# [CV] activation=relu, alpha=0.0001, hidden_layer_sizes=200, learning_rate_init=0.0001
# [CV]  activation=relu, alpha=0.0001, hidden_layer_sizes=200, learning_rate_init=0.0001, score=-1.7126319098627587, total=   3.2s
# [CV] activation=relu, alpha=0.0001, hidden_layer_sizes=200, learning_rate_init=0.0001
# [CV]  activation=relu, alpha=0.0001, hidden_layer_sizes=200, learning_rate_init=0.0001, score=-1.6489932383649324, total=   1.4s
# [CV] activation=relu, alpha=0.0001, hidden_layer_sizes=200, learning_rate_init=0.0001
# [CV]  activation=relu, alpha=0.0001, hidden_layer_sizes=200, learning_rate_init=0.0001, score=-1.6023573232707438, total=   2.7s
# [CV] activation=relu, alpha=0.0001, hidden_layer_sizes=200, learning_rate_init=0.0001
# [CV]  activation=relu, alpha=0.0001, hidden_layer_sizes=200, learning_rate_init=0.0001, score=-1.7791207457040805, total=   2.4s
# [Parallel(n_jobs=1)]: Done 360 out of 360 | elapsed:  8.3min finished
# GridSearchCV(cv=KFold(n_splits=5, random_state=42, shuffle=True),
#        error_score='raise',
#        estimator=MLPRegressor(activation='relu', alpha=0.0001, batch_size='auto', beta_1=0.9,
#        beta_2=0.999, early_stopping=False, epsilon=1e-08,
#        hidden_layer_sizes=(100,), learning_rate='constant',
#        learning_rate_init=0.001, max_iter=1000, momentum=0.9,
#        nesterovs_momentum=True, power_t=0.5, random_state=42, shuffle=True,
#        solver='adam', tol=0.0001, validation_fraction=0.1, verbose=False,
#        warm_start=False),
#        fit_params=None, iid=True, n_jobs=1,
#        param_grid={'hidden_layer_sizes': [50, 100, 150, 200], 'activation': ['logistic', 'relu'], 'learning_rate_init': [0.01, 0.001, 0.0001], 'alpha': [0.01, 0.001, 0.0001]},
#        pre_dispatch='2*n_jobs', refit=True, return_train_score='warn',
#        scoring='neg_mean_absolute_error', verbose=10)

# %%
mlp_6_GS.best_params_
# Out:
# {'activation': 'relu',
#  'alpha': 0.01,
#  'hidden_layer_sizes': 150,
#  'learning_rate_init': 0.01}

# %%
mlp_6_mod = MLPRegressor(activation='relu', alpha=0.01, batch_size='auto', beta_1=0.9,
       beta_2=0.999, early_stopping=False, epsilon=1e-08,
       hidden_layer_sizes=(150,), learning_rate='constant',
       learning_rate_init=0.01, max_iter=1000, momentum=0.9,
       nesterovs_momentum=True, power_t=0.5, random_state=42,
       shuffle=True, solver='adam', tol=0.0001, validation_fraction=0.1,
       verbose=False, warm_start=False)

# %%
cross_val(X_6, y_6, mlp_6_mod)
# Out:
# MAE: 1.6397 (0.0666)
# MSE: 4.1763 (0.3227)
# -----------------------------------------

# %%
mlp_6_mod.fit(X_6, y_6)
# Out:
# MLPRegressor(activation='relu', alpha=0.01, batch_size='auto', beta_1=0.9,
#        beta_2=0.999, early_stopping=False, epsilon=1e-08,
#        hidden_layer_sizes=(150,), learning_rate='constant',
#        learning_rate_init=0.01, max_iter=1000, momentum=0.9,
#        nesterovs_momentum=True, power_t=0.5, random_state=42, shuffle=True,
#        solver='adam', tol=0.0001, validation_fraction=0.1, verbose=False,
#        warm_start=False)

# %%
show_preds(mlp_6_mod, X_6, y_6, df_6_all)

# %% [markdown]
# # 2017 Season Results

# %% [markdown]
# Calculation of the season average score using the best performing Models for each position.

# %%
# All of the available rounds for the 2017 season.
list_rounds = df_1_2017['Round'].unique()

# %%
# For each position, get a list (more efficient working with lists than dataframes) 
# of the top predicted scoring athletes, using the established best performing models.
# The Team Formation is 4-4-2 with a coach (Position 6).

list1 = get_preds(df_1_2017, mlp_1_mod, model_params_1, 1)
print('List 1 done.')
list2 = get_preds(df_2_2017, mlp_2_mod, model_params_2, 2)
print('List 2 done.')
list3 = get_preds(df_3_2017, mlp_3_mod, model_params_3, 2)
print('List 3 done.')
list4 = get_preds(df_4_2017, mlp_4_mod, model_params_4, 4)
print('List 4 done.')
list5 = get_preds(df_5_2017, mlp_5_mod, model_params_5, 2)
print('List 5 done.')
list6 = get_preds(df_6_2017, mlp_6_mod, model_params_6, 1)
print('List 6 done.')
# Out:
# List 1 done.
# List 2 done.
# List 3 done.
# List 4 done.
# List 5 done.
# List 6 done.

# %%
# Transform the lists with best choices for each position into a dataframe for easier calculations and visualizations.

columns = ['AthleteID', 'Position', 'Points', 'Round', 'Prediction', 'Price', 'Price_Variation']
df_ = pd.DataFrame(columns = columns)

list_total = []
print(len(list_total))

list_total = list1
print(len(list_total))
list_total.extend(list2)
print(len(list_total))
list_total.extend(list3)
print(len(list_total))
list_total.extend(list4)
print(len(list_total))
list_total.extend(list5)
print(len(list_total))
list_total.extend(list6)
print(len(list_total))

df_ = pd.DataFrame(list_total, columns= columns)
# Out:
# 0
# 36
# 108
# 180
# 324
# 396
# 432

# %%
# Define what the cost for constructing the team was.
df_['Price_prev'] = df_['Price'] - df_['Price_Variation']

# %%
# Group the sum of scores per round.
df_sums = df_.groupby(['Round']).sum()

# %%
# Establish a Profit/Loss per round in 'Cartoletas' and what the acummulated value for these variations is per round.
df_sums['Profit'] = df_sums['Price'] - df_sums['Price_prev']
df_sums['Bank'] = df_sums['Profit'].cumsum()

# %% [markdown]
# The summary for each of the predicted rounds with their scores and added information.

# %%
df_sums
# Out:
#        AthleteID  Position  Points  Prediction    Price  Price_Variation  \
# Round
# 2         879797        43 33.7200     61.2257 163.4400           7.3700
# 3         915402        43 18.0500     55.8163 157.0200         -13.6100
# 4         726157        43 35.0200     59.5200 180.4900          -3.2700
# 5         841203        43 54.4500     54.5477 146.6000           0.1200
# 6         809855        43 90.6100     63.7214 159.4500           6.0800
# 8         875212        43 75.9900     59.4529 172.9300           9.8500
# 9         754471        43 89.7000     76.7847 174.0600           9.2500
# 10        886458        43 41.2100     80.5076 157.3700          -4.8500
# 11        751399        43 81.2600     64.9178 175.0100           8.2500
# 12        862081        43 46.0500     63.6619 179.7400          -2.7800
# 13        766713        43 42.9700     50.6363 158.1200          -4.8100
# 14        792799        43 35.2500     63.1202 163.3000          -4.0200
# 15        682987        43 51.7800     57.5187 150.9300           2.6900
# 16        814159        43 59.1800     64.9801 160.8500          -0.5300
# 17        676249        43 44.9600     53.7231 151.8600          -1.9800
# 18        657094        43 50.0700     58.3763 166.2700          -2.0600
# 19        811520        43 38.4500     60.8681 161.5000          -4.9400
# 20        845836        43 15.6800     63.1747 130.5200          -5.1200
# 21        782044        43 57.8300     61.0000 167.5200          -1.1200
# 22        862816        43 20.8600     63.0240 137.2400          -7.4100
# 23        872105        43 44.2300     57.1755 123.9300          -0.9200
# 24        689916        43 43.8000     59.5279 156.0700           0.5400
# 25        826297        43 58.4300     54.6894 153.9500           1.4800
# 26        790228        43 43.2100     58.9307 173.9700           0.2300
# 27        964035        43 60.2500     56.7176 165.2300           2.2800
# 28        795133        43 58.1600     54.2543 159.3800           1.6900
# 29        814960        43 76.5400     53.1356 181.6600           4.5400
# 30        689858        43 66.9500     58.5519 183.7800          -0.9600
# 31        710562        43 55.5000     57.1754 147.5800          -3.0200
# 32        873856        43 97.5800     58.7908 149.8100           8.1800
# 33        762107        43 48.9800     58.6315 147.5900          -2.4800
# 34        912032        43 39.1700     59.8068 153.8100          -4.0300
# 35        887802        43 32.3900     60.3173 169.5100          -5.2000
# 36        854342        43 65.8500     56.6848 139.1200           2.4000
# 37        897336        43 47.3500     60.9108 175.5200          -3.9100
# 38        842151        43 64.8800     55.0981 146.4500          -2.1700
#
#        Price_prev   Profit     Bank
# Round
# 2        156.0700   7.3700   7.3700
# 3        170.6300 -13.6100  -6.2400
# 4        183.7600  -3.2700  -9.5100
# 5        146.4800   0.1200  -9.3900
# 6        153.3700   6.0800  -3.3100
# 8        163.0800   9.8500   6.5400
# 9        164.8100   9.2500  15.7900
# 10       162.2200  -4.8500  10.9400
# 11       166.7600   8.2500  19.1900
# 12       182.5200  -2.7800  16.4100
# 13       162.9300  -4.8100  11.6000
# 14       167.3200  -4.0200   7.5800
# 15       148.2400   2.6900  10.2700
# 16       161.3800  -0.5300   9.7400
# 17       153.8400  -1.9800   7.7600
# 18       168.3300  -2.0600   5.7000
# 19       166.4400  -4.9400   0.7600
# 20       135.6400  -5.1200  -4.3600
# 21       168.6400  -1.1200  -5.4800
# 22       144.6500  -7.4100 -12.8900
# 23       124.8500  -0.9200 -13.8100
# 24       155.5300   0.5400 -13.2700
# 25       152.4700   1.4800 -11.7900
# 26       173.7400   0.2300 -11.5600
# 27       162.9500   2.2800  -9.2800
# 28       157.6900   1.6900  -7.5900
# 29       177.1200   4.5400  -3.0500
# 30       184.7400  -0.9600  -4.0100
# 31       150.6000  -3.0200  -7.0300
# 32       141.6300   8.1800   1.1500
# 33       150.0700  -2.4800  -1.3300
# 34       157.8400  -4.0300  -5.3600
# 35       174.7100  -5.2000 -10.5600
# 36       136.7200   2.4000  -8.1600
# 37       179.4300  -3.9100 -12.0700
# 38       148.6200  -2.1700 -14.2400

# %%
# Season 2017 Average
avg = df_sums.Points.sum()/df_sums.Points.count()
print('The 2017 Total Season Average Score was %.4f.' % (avg))
# Out:
# The 2017 Total Season Average Score was 52.3989.

# %% [markdown]
# ### Average Scoring per Position

# %%
# Group the dataframe for each position (1-6) by their mean values.
df_mean = df_.groupby(['Position']).mean()

# %%
df_mean
# Out:
#           AthleteID  Points   Round  Prediction   Price  Price_Variation  \
# Position
# 1        57303.7778  3.3194 20.3611      3.6799 15.6725           0.0850
# 2        71851.0833  3.5222 20.3611      5.5187  9.3406           0.0883
# 3        69001.3889  3.7806 20.3611      4.9651  8.6517           0.0728
# 4        66003.2222  4.7326 20.3611      4.9114 15.5796          -0.1319
# 5        74691.0278  5.1250 20.3611      5.5174 16.2847          -0.3260
# 6        58067.7778  5.2933 20.3611      4.5881 12.9436           0.3769
#
#           Price_prev
# Position
# 1            15.5875
# 2             9.2522
# 3             8.5789
# 4            15.7115
# 5            16.6107
# 6            12.5667

# %% [markdown]
# ## 2017 Season MAE Results

# %% [markdown]
# Calculation of the MAE results for the 2017 season.

# %%
from sklearn.metrics import mean_absolute_error

# %%
'''
Simple function for calculating the MAE for the given model, parameters, and dataframe.
'''
def get_test_score(model, df, params):
    preds = model.predict(df[params].as_matrix())
    err = mean_absolute_error(df['Points'], preds)
    print(err)

# %%
print('2017 MAE results:')
print('----------------------')
print('Position 1:')
get_test_score(mlp_1_mod, df_1_2017, model_params_1)
print('Position 2:')
get_test_score(mlp_2_mod, df_2_2017, model_params_2)
print('Position 3:')
get_test_score(mlp_3_mod, df_3_2017, model_params_3)
print('Position 4:')
get_test_score(mlp_4_mod, df_4_2017, model_params_4)
print('Position 5:')
get_test_score(mlp_5_mod, df_5_2017, model_params_5)
print('Position 6:')
get_test_score(mlp_6_mod, df_6_2017, model_params_6)
# Out:
# 2017 MAE results:
# ----------------------
# Position 1:
# 4.709960175622044
# Position 2:
# 3.307703561011065
# Position 3:
# 2.9871578776844645
# Position 4:
# 2.9947236368867407
# Position 5:
# 3.5071098007802686
# Position 6:
# 1.6225820232706516
